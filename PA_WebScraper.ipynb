# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
HOME_URL = 'https://www.panamaamerica.com.pa'

# %%
r = requests.get(HOME_URL)
print(f'Status Code: {r.status_code}')
# Out:
# Status Code: 200

# %%
home_soup = BeautifulSoup(r.content, 'lxml')
print(home_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="160647454000723" property="fb:pages"/>
#   <title>
#    Panamá América | Noticias de Panamá y el mundo
#   </title>
#   <link as="style" href="/sites/all/themes/panamaamerica_materialize/css/materialize-cols-min.css" rel="preload"/>
#   <link as="style" href="/sites/all/themes/panamaamerica_materialize/css/custom.css?45" rel="preload"/>
#   <link as="script" href="https://www.panamaamerica.com.pa/sites/default/files/js/js_38VWQ3jjQx0wRFj7gkntZr077GgJoGn5nv3v05IeLLo.js" rel="preload"/>
#   <link as="script" href="https://www.panamaamerica.com.pa/sites/default/files/js/js_KqhyK1UJp8ny-5ZZVLo14BE1BFMvBVOI2dYTTz-B0dw.js" rel="preload"/>
#   <link href="https://cdn.lavoz.com.ar" rel="preconnect"/>
#   <link as="script" href="/sites/all/themes/panamaamerica_materialize/js/swiper.min.js" rel="preload"/>
#   <meta content="Noticias de Panamá e información de última hora sobre actualidad, economía, política, mundo, opinión, deportes, variedades y más en Panamá América." name="description"/>
#   <meta content="Panamá América" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.panamaamerica.com.pa/" property="og:url"/>
#   <meta content="Panamá América" property="og:title"/>
#   <meta content="Noticias de última hora sobre la actualidad en Panamá y el mundo." property="og:description"/>
#   <meta content="https://www.panamaamerica.com.pa/img/panamaamerica-horizontal.jpg" property="og:image"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@PanamaAmerica" name="twitter:site"/>
#   <meta content="@PanamaAmerica" name="twitter:creator"/>
#   <meta content="https://www.panamaamerica.com.pa/front18" name="twitter:url"/>
#   <meta content="Panamá América" name="twitter:title"/>
#   <meta content="frontpage" name="cXenseParse:pageclass"/>
#   <link href="/img/apple-touch-icon-iphone-60x60.png" rel="apple-touch-icon"/>
#   <link href="/img/apple-touch-icon-ipad-76x76.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/img/apple-touch-icon-iphone-retina-120x120.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/img/apple-touch-icon-ipad-retina-152x152.png" rel="apple-touch-icon" sizes="144x144"/>
#   <meta content="2f13e663f124tajn2emw5q6t9dc6sp" name="facebook-domain-verification"/>
#   <meta content="News" name="genre"/>
#   <meta content="Panamá América" name="author"/>
#   <meta content="Panama" name="geo.placename"/>
#   <meta content="es" name="language"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="noticias de panama, panamá, mundo, hoy, panamaamerica.com.pa, actualidad, periodico, economia, farandula, politica, deportes" name="keywords"/>
#   <meta content="https://www.panamaamerica.com.pa/img/panamaamerica-horizontal.jpg" name="twitter:image"/>
#   <link href="https://www.panamaamerica.com.pa/rss/recent/index.xml" rel="alternate" type="application/rss+xml"/>
#   <script type="application/ld+json">
#    [{"@context": "http://schema.org","@type": "Organization","name": "Panamá América","url": "https://www.panamaamerica.com.pa","sameAs": ["https://www.panamaamerica.com.pa/rss/recent/index.xml"],"logo": {"@context": "http://schema.org","@type": "ImageObject","url": "https://www.panamaamerica.com.pa/img/pa-logo-cuadrado-800.jpg","width": "800","height": "800"}}, {"@context": "http://schema.org","@type": "WebSite","name": "Panamá América","url": "https://www.panamaamerica.com.pa/","sameAs": ["https://www.youtube.com/user/diariopanamaamerica", "https://twitter.com/PanamaAmerica", "https://www.facebook.com/PanamaAmerica.com.pa", "https://www.instagram.com/panamaamerica/", "https://www.panamaamerica.com.pa/rss/recent/index.xml"]}]
#   </script>
#   <link href="https://www.panamaamerica.com.pa/" rel="canonical"/>
#   <link as="image" href="/img/covid-2021/covid-especial-2021.jpeg" rel="preload"/>
#   <link href="/sites/all/themes/panamaamerica_materialize/css/materialize-cols-min.css?v3" media="all" rel="stylesheet" type="text/css"/>
#   <meta content="0" name="node-count"/>
#   <link href="https://www.panamaamerica.com.pa/img/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://www.panamaamerica.com.pa/img/favicon.png" rel="shortcut icon" type="image/png"/>
#   <link href="/sites/all/themes/panamaamerica_materialize/css/custom.css?g2f25353h232s" rel="stylesheet" type="text/css"/>
#   <link as="style" href="https://fonts.googleapis.com/css?family=Montserrat&amp;display=swap" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#   <script>
#    const panamaamerica = JSON.parse('{"url":"\/\/www.panamaamerica.com.pa","path":"\/","contentType":"page","paywallUrl":"https:\/\/suscripcion.panamaamerica.com.pa","paywallType":"free_access","isPremium":false,"category":null,"allowedContentTypes":["article","video","galeria"],"params":{"registro":false,"login":""}}');const device = screen.width;panamaamerica.device = (device<800) ? 'mobile':'desktop';window.paywallConfig = {paywallUrl:panamaamerica.paywallUrl,async: true,type: panamaamerica.paywallType,contentType: panamaamerica.contentType,cookieDomain: '.panamaamerica.com.pa', debug: false,loginwallLimit: panamaamerica.isPremium ? 0 : 9999999 , paywallLimit: 9999999, category: panamaamerica.category,allowedContentTypes: panamaamerica.allowedContentTypes};     window.paywall = window.paywall || {};    paywall.queue = window.paywall.queue || [];        (async () => {const user = await getUser();if(user !== null){ paywall.queue.push(['invoke', 'signIn', {id: user.id,email: user.email,first_name: user.first_name,last_name: user.last_name,avatar: null,gender: user.gender,age: user.age,phone: user.phone,tipo_doc: user.tipo_doc,num_doc: user.num_doc,roles: user.roles}]);}else{try{paywall.signOff();}catch (e){console.log(e);}}paywall.queue.push(['addEventListener', 'loginwall', function (event) {if(panamaamerica.isPremium === true){bloquearArticulo();}}]); paywall.queue.push(['invoke', 'check']);crearMenu(user);if(panamaamerica.params.login){mostrarIniciarSesion();}if(panamaamerica.params.registro){mostrarCrearCuenta();}enviarDatosGa(user);    })();function enviarDatosGa(user){const upUrl = new URL( document.URL.split('?')[0] );var send = false;if( panamaamerica.isPremium ){upUrl.searchParams.set('cc', 'true');send = true;}if(user){upUrl.searchParams.set('lg', 'true');send = true;}console.log('%c upUrl ==============> '+ upUrl.href, "color: blue");  }function crearMenu(user){let oldReg = document.querySelector('.menuregistro');if(oldReg != null) oldReg.outerHTML="";var menuRegistro = document.querySelector('.menuregistro-2021');if(menuRegistro != null) menuRegistro.style.display="flex";if(user === null){  if(document.cookie.split("gtx8id")[1]!==undefined){document.cookie = "gtx8id=null;expires=Thu, 01 Jan 1970 00:00:00 GMT;path=/";}if(panamaamerica.device == "desktop"){menuRegistro.querySelector('.reg-left').innerHTML ='<img src="https://www.panamaamerica.com.pa/img/login/user_male_w.png" width="25" height="25" alt>';menuRegistro.querySelector('.reg-center').innerHTML ='<span onclick="mostrarIniciarSesion()">Ingresar</span>';}else{menuRegistro.querySelector('.reg-center').innerHTML = '<img src="/img/login/user_male_off_2_azul.webp" width="30" height="30" alt="Iniciar Sesión o Crear Cuenta">';menuRegistro.setAttribute('onclick', 'mostrarIniciarSesion()');}}else{setUserData(user.id, user.name, user.email);document.querySelector('.mi-membresia-li').innerHTML ='<a href="https://suscripcion.panamaamerica.com.pa/mi-suscripcion" target="_blank" rel="nofollow noopener"><img src="/img/login/iconos/membresia.png" alt><span>Mi suscripción</span></a>';document.querySelector('.cerrar-sesion-li').innerHTML ='<a href="//registro.panamaamerica.com.pa/login/logout.php?referido=//www.panamaamerica.com.pa" rel="nofollow"><img src="/img/login/iconos/salir.png" alt><span>Cerrar sesión</span></a>';if(panamaamerica.device == "desktop"){menuRegistro.querySelector('.reg-left').innerHTML ='<img src="/img/login/user_male_online.png" width="25" height="25" alt>';menuRegistro.querySelector('.reg-center').innerHTML ='<span onclick="toogleUserMenu()">'+ user.first_name.split(' ')[0] +'</span>';menuRegistro.querySelector('.reg-right').innerHTML ='<div onclick="toogleUserMenu()"></div>';}else{menuRegistro.querySelector('.reg-center').innerHTML = '<img src="/img/login/user_male_online_2_verde_4.png?123" width="30" height="30" alt="Registro">';document.querySelector('.reg-center').setAttribute('onclick', 'toogleUserMenu()');}}}async function getUser() {const nodeC ...
#   </script>
#   <script src="//code.jquery.com/jquery-3.1.1.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# window.jQuery || document.write("<script src='/sites/all/modules/jquery_update/replace/jquery/3.1/jquery.min.js'>\x3C/script>")
# //--><!]]>
#   </script>
#   <script src="https://www.panamaamerica.com.pa/sites/default/files/js/js_38VWQ3jjQx0wRFj7gkntZr077GgJoGn5nv3v05IeLLo.js" type="text/javascript">
#   </script>
#   <script src="https://www.panamaamerica.com.pa/sites/default/files/js/js_KqhyK1UJp8ny-5ZZVLo14BE1BFMvBVOI2dYTTz-B0dw.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# (function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","https://www.google-analytics.com/analytics.js","ga");ga("create", "UA-1122582-1", {"cookieDomain":".panamaamerica.com.pa"});ga("send", "pageview");
# //--><!]]>
#   </script>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"panamaamerica_materialize","theme_token":"Nb7sBQcL3qk-SJTytPYpdA7o8wpP7ncKzVLgRNcKmnI","js":{"\/\/code.jquery.com\/jquery-3.1.1.min.js":1,"0":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"public:\/\/languages\/es_ENITyuaOjDjrnwcGXmpoOAwgoLmMLYIE2P9TxYKk6kI.js":1,"sites\/all\/modules\/google_analytics\/googleanalytics.js":1,"1":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"sites\/all\/modules\/date\/date_api\/date.css":1,"sites\/all\/modules\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"modules\/poll\/poll.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/views\/css\/views.css":1,"sites\/all\/modules\/ctools\/css\/ctools.css":1,"sites\/all\/themes\/panamaamerica_materialize\/css\/style.css":1,"sites\/all\/themes\/panamaamerica_materialize\/css\/materialize.min.css":1}},"googleanalytics":{"trackOutbound":1,"trackMailto":1,"trackDownload":1,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip","trackDomainMode":1}});
# //--><!]]>
#   </script>
#   <script type="text/javascript">
#    function readCookie(name) {
# var nameEQ = name + "=";
# var ca = document.cookie.split(';');
# for(var i=0;i < ca.length;i++) {
# var c = ca[i];
# while (c.charAt(0)==' ') c = c.substring(1,c.length);
# if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length,c.length);
# }
# return null;
# }
# function getExternalUserId()
# {
# var usermailfinal = localStorage.getItem("paregmailuser");
# if (typeof usermailfinal !== "undefined" && usermailfinal != null)
# return atob(usermailfinal);
# else return;
# };
#   </script>
#   <script src="https://scdn.cxense.com/cx.js" type="text/javascript">
#   </script>
#   <script>
#    var cX = cX || {}; cX.callQueue = cX.callQueue || [];
# cX.callQueue.push(['setSiteId', '1139591241309920180' ]);
# cX.callQueue.push(['cint', '200']);
# cX.callQueue.push(['invoke', function() {
# var cookieValue = cX.getUserSegmentIds({persistedQueryId:'14579d7bfbef7ecfaa2e4f59148bd4977cc26d2c'}).join('|');
# var expireDate = new Date(new Date().getTime() + 180 * 1000 * 60 * 60 * 24).toGMTString();
# document.cookie = 'cxSegmentos=' + cookieValue + ';expires=' + expireDate + ';path=/';}
# ]);
# var externalUserId = getExternalUserId();
# if (typeof externalUserId !== "undefined" && externalUserId != null) {
# cX.callQueue.push(["addExternalId", {"id": externalUserId,"type":"epa"}]);
# }
# cX.callQueue.push(['sendPageViewEvent']);
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PFPDQDP');
#   </script>
#   <script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# googletag.cmd.push(function () {
# var REFRESH_KEY = "refresh";
# var REFRESH_VALUE = "true";
# var mapping1 =
# googletag.sizeMapping()
# .addSize([980, 200], [[970, 90],[728, 90],[970, 250],])
# .addSize([640, 200], [[336, 280],[300, 250],[320, 50],[320, 100],[300, 50],[300, 100],[468, 60],[300, 600],])
# .addSize([336, 200], [[336, 280],[300, 250],[320, 50],[320, 100],[300, 50],[300, 100],[300, 600],])
# .addSize([0, 0], [])
# .build();
# var mapping2 =
# googletag.sizeMapping()
# .addSize([300, 50], [[300, 250],[320, 50],[300, 50],[300, 100],])
# .build();
# var mappingFixed =
# googletag.sizeMapping()
# .addSize([980, 200], [[728, 90]])
# .addSize([640, 200], [[240, 50],[240, 100],[320, 50],[320, 100],[300, 50],[320, 50]])
# .addSize([336, 200], [[240, 50],[240, 100],[320, 50],[320, 100],[300, 50],[320, 50]])
# .addSize([0, 0], [])
# .build();
# var sidebar =
# googletag.sizeMapping()
# .addSize([300, 50], [[300, 250],[320, 50],[300, 50],[300, 100],[336, 280],[320, 50],[320, 100],])
# .build();
# //start slot declaration
# googletag.defineSlot('/1056710/pa-top-1', [[970, 250], [950, 90], [930, 180], [710, 90], [970, 66], [980, 120], [728, 180], [750, 200], [630, 80], [468, 60], [980, 90], [750, 100], [960, 90], [728, 90], [970, 90]], 'div-gpt-ad-1642447218029-0')
# .defineSizeMapping(mapping1)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio3_728x90_970x90_DT', [[468, 60], [300, 250], [300, 100], [728, 90], [320, 100], [300, 50], [336, 280], [320, 50], [970, 250], [970, 90], [300, 600]], 'div-gpt-ad-1636993452963-0')
# .defineSizeMapping(mapping1)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio4_728x90_970x90_DT', [[300, 50], [300, 600], [300, 100], [728, 90], [320, 100], [970, 90], [320, 50], [468, 60], [970, 250], [300, 250], [336, 280]], 'div-gpt-ad-1636994012933-0')
# .defineSizeMapping(mapping1)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio5_728x90_970x90_DT', [[468, 60], [300, 250], [970, 250], [970, 90], [300, 100], [320, 100], [300, 50], [728, 90], [320, 50], [300, 600], [336, 280]], 'div-gpt-ad-1636994317563-0')
# .defineSizeMapping(mapping1)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio6_728x90_970x90_DT', [[320, 100], [320, 50], [300, 600], [970, 250], [728, 90], [336, 280], [300, 250], [468, 60], [970, 90], [300, 100], [300, 50]], 'div-gpt-ad-1636994366268-0')
# .defineSizeMapping(mapping1)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio7_728x90_970x90_DT', [[300, 250], [300, 100], [728, 90], [320, 100], [300, 50], [336, 280], [970, 250], [970, 90], [320, 50], [468, 60], [300, 600]], 'div-gpt-ad-1636994478811-0')
# .defineSizeMapping(mapping1)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio8_728x90_970x90_DT', [[300, 250], [970, 250], [336, 280], [970, 90], [320, 50], [468, 60], [300, 600], [320, 100], [728, 90], [300, 50], [300, 100]], 'div-gpt-ad-1636994530744-0')
# .defineSizeMapping(mapping1)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio13_300x250_300x50_300x100_DT', [[300, 100], [300, 50], [300, 250]], 'div-gpt-ad-1636995632841-0')
# .defineSizeMapping(mapping2)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# //PARA SIDEBAR 3 bloques
# googletag.defineSlot('/1056710/espacio1_300x250_336x280_DT', [[300, 50], [300, 100], [320, 50], [320, 100], [300, 250], [336, 280]], 'div-gpt-ad-1636994881199-0')
# .defineSizeMapping(sidebar)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio2_300x250_336x280_DT', [[300, 250], [336, 280], [320, 50], [320, 100], [300, 50], [300, 100]], 'div-gpt-ad-1636994889452-0')
# .defineSizeMapping(sidebar)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio16_300x250_336x280_DT', [[320, 100], [728, 90], [320, 50], [300, 600], [970, 250], [336, 280], [300, 250], [468, 60], [970, 90], [300, 100], [300, 50]], 'div-gpt-ad-1639162125989-0')
# .defineSizeMapping(sidebar)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# //fixed abajo de pagina
# googletag.defineSlot('/1056710/espacio15_300x250_336x280_DT', [[300, 250], [970, 250], [336, 280], [970, 90], [320, 50], [468, 60], [300, 600], [320, 100], [728, 90], [300, 50], [300, 100]], 'div-publicidade-fixorodape')
# .defineSizeMapping(mappingFixed)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/EspacioIntersticial1', [1, 1], 'div-gpt-ad-1639162438050-0').addService(googletag.pubads());
# //end slot declaration
# //Start refresh
# //developer docs: https://developers.google.com/doubleclick-gpt/guides/control-ad-loading
# var SECONDS_TO_WAIT_AFTER_VIEWABILITY = 30;
# googletag
# .pubads()
# .addEventListener("impressionViewable", function (event) {
# var slot = event.slot;
# if (slot.getTargeting(REFRESH_KEY).indexOf(REFRESH_VALUE) > -1) {
# setTimeout(function () {
# if (slot.getTargeting("refreshed_slot")) {
# slot.setTargeting("refreshed_slot", "true");
# }
# googletag.pubads().refresh([slot]);
# }, SECONDS_TO_WAIT_AFTER_VIEWABILITY * 1000);
# }
# });
# //End refresh
# //Start Lazy Load
# //developer docs: https://developers.google.com/doubleclick-gpt/samples/lazy-loading
# googletag.pubads().enableLazyLoad({
# fetchMarginPercent: 200,
# renderMarginPercent: 200,
# mobileScaling: 2.0,
# });
# //End lazy load
# //key values segmentation
# //developer docs: https://developers.google.com/doubleclick-gpt/guides/key-value-targeting
# googletag.pubads().setTargeting("categoria", ["economy","world","sports"]);
# googletag.pubads().setTargeting("tags", ["dolar", "futbol", "dog"]);
# googletag.pubads().setTargeting("idArticle", ["1234567"]);
# //googletag.pubads().enableSingleRequest(); //with this line active, lazy load won't work
# googletag.pubads().collapseEmptyDivs();
# googletag.pubads().setCentering(true);
# googletag.enableServices();
# // This listener will be called when a slot has finished rendering.
# googletag.pubads().addEventListener('slotRenderEnded', function(event) {
# var slot = event.slot;
# console.group('Slot', slot.getSlotElementId(), 'finished rendering.');
# // Log details of the rendered ad.
# console.log('Advertiser ID:', event.advertiserId);
# console.log('Campaign ID: ', event.campaignId);
# console.log('Creative ID: ', event.creativeId);
# console.log('Is empty?:', event.isEmpty);
# console.log('Line Item ID:', event.lineItemId);
# console.log('Size:', event.size);
# console.groupEnd();
# if (slot.getSlotElementId() === "div-publicidade-fixorodape" && event.isEmpty) {
# console.log("anchor banner is empty")
# }
# });
# });
# //End HEAD code
#   </script>
#   <script type="text/javascript">
#    window._taboola = window._taboola || [];
# _taboola.push({
# home: 'auto'
# });
# ! function(e, f, u, i) {
# if (!document.getElementById(i)) {
# e.async = 1;
# e.src = u;
# e.id = i;
# f.parentNode.insertBefore(e, f);
# }
# }(document.createElement('script'),
# document.getElementsByTagName('script')[0],
# '//cdn.taboola.com/libtrc/epasa-network/loader.js',
# 'tb_loader_script');
# if (window.performance && typeof window.performance.mark == 'function') {
# window.performance.mark('tbl_ic');
# }
#   </script>
#  </head>
#  <body class="html front not-logged-in two-sidebars page-front18 i18n-es">
#   <div id="skip-link">
#    <a class="element-invisible element-focusable" href="#middle-content">
#     Pasar al contenido principal
#    </a>
#   </div>
#   <div id="div-gpt-ad-1639162438050-0">
#    <script>
#     googletag.cmd.push(function() { googletag.display('div-gpt-ad-1639162438050-0'); });
#    </script>
#   </div>
#   <div class="clearfix" id="footer">
#    <section class="block block-block clearfix" id="block-block-742">
#     <style>
#      .eplad{
# width:100%;
# margin: 0 auto;
# text-align: center;
# }@media only screen and (min-width: 801px) {
# .eplad{
# max-width:970px;
# }
# }
#     </style>
#     <div class="eplad">
#      <script language="JavaScript" type="text/javascript">
#       <!--
# var eplDoc = document, eplLL = false, eS1 = 'us.img.e-planning.net', eplArgs = { iIF:1,sV: schemeLocal() + "://ads.us.e-planning.net/" ,vV:"4",sI:"b7e6",kVs:{  }};
# function eplCheckStart() {
# if (document.epl) {
# var e = document.epl;
# if (e.eplReady()) return true;
# e.eplInit(eplArgs);
# if (eplArgs.custom) {
# for (var s in eplArgs.custom) {
# e.setCustomAdShow(s, eplArgs.custom[s]);
# }
# }
# return e.eplReady();
# } else if (!eplLL) {
# var epl41Script = document.createElement('SCRIPT'); epl41Script.async = true;
# epl41Script.src = schemeLocal() + '://' + eS1 + '/layers/epl-41.js';
# document.head.appendChild(epl41Script);
# eplLL = true;
# }
# return false;
# }
# eplCheckStart();
# function eplSetAd(eID) {
# var opts;
# if (eplCheckStart()) {
# if (eplArgs.sOpts && eplArgs.sOpts[eID]) {
# opts = eplArgs.sOpts[eID];
# if (opts.custF) { document.epl.setCustomAdShow(eID,opts.custF); }
# } else { opts = {}; }
# document.epl.setSpace(eID, opts);
# } else {
# setTimeout(eplSetAd.bind(null, eID), 250);
# }
# }
# function eplAD4(eID, opts) {
# document.write('<div id="eplAdDiv'+eID+'"></div>');
# if (!eplArgs.sOpts) { eplArgs.sOpts = {}; }
# eplArgs.sOpts[eID] = opts || {t:1};
# eplSetAd(eID);
# }
# function schemeLocal() {
# protocol = document.location.protocol || window.top.location.protocol;
# if (protocol) {
# return protocol.indexOf('https') !== -1 ? 'https' : 'http';
# }
# }
# //-->
#      </script>
#      <script>
#       if(panamaamerica.device =="desktop"){
# eplAD4("df8f36e09de2f418",{t:1,timeout:0,ma:1,custF:null,wh:"970x90",sd:"b7e6!!" + schemeLocal() + "://ads.us.e-planning.net/!!", });
# }
# else{
# eplAD4("de59b31395817066",{t:1,timeout:0,ma:1,custF:null,wh:"320x50",sd:"b7e6!!" + schemeLocal() + "://ads.us.e-planning.net/!!", p:"1b6494c8d76ffe6c"});
# }
#      </script>
#     </div>
#    </section>
#   </div>
#   <div class="" id="page">
#    <header class="main-header-2019">
#     <div class="main-header-top">
#      <div class="search-2021">
#      </div>
#      <div class="secciones-label-container">
#       <span class="secciones-label hide20-for-small-only">
#        Secciones
#       </span>
#       <div class="main-menu-x">
#        <div class="openmenu2">
#         <div class="bar1">
#         </div>
#         <div class="bar2">
#         </div>
#         <div class="bar3">
#         </div>
#        </div>
#        <div class="bloquear-pag">
#        </div>
#        <div class="links-wrapper">
#         <ul class="links clearboth" id="main-menu-links">
#          <li class="hide20-for-desktop-only">
#           <div class="buscador-header-2019">
#            <form action="//www.panamaamerica.com.pa/buscador" id="search-m" method="get">
#             <input name="cx" type="hidden" value="006265388743205756159:y9ktgnu2wsw"/>
#             <input name="cof" type="hidden" value="FORID:11"/>
#             <input class="buscador-input-txt-2019-m" height="20px" id="qq2" name="string" placeholder="Buscar..." size="70" style="visibility: visible !important; margin:auto; width: 60%;" type="text"/>
#             <label for="btn-cont-search-m">
#              <i aria-hidden="true" class="fa fa-search search-submit-btn-19x" style="padding-right:10px;" type="">
#              </i>
#             </label>
#             <input class="btn-cont-search-m" id="btn-cont-search-m" style="display:none;" type=""/>
#            </form>
#            <li class="menu-nacion has-sub">
#             <a href="/actualidad">
#              Actualidad
#             </a>
#             <ul class="dropdown">
#              <li>
#               <a href="/politica">
#                Política
#               </a>
#              </li>
#              <li>
#               <a href="/sociedad">
#                Sociedad
#               </a>
#              </li>
#              <li>
#               <a href="/judicial">
#                Judicial
#               </a>
#              </li>
#              <li>
#               <a href="/provincias">
#                Provincias
#               </a>
#              </li>
#              <li>
#               <a href="/mundo">
#                Mundo
#               </a>
#              </li>
#              <li>
#               <a href="/tema/el-trino">
#                El Trino
#               </a>
#              </li>
#              <li>
#               <a href="/aldea-global">
#                Aldea Global
#               </a>
#              </li>
#             </ul>
#             <div class="flecha-ddown">
#              <span>
#              </span>
#             </div>
#            </li>
#            <li class="menu-opinion has-sub">
#             <a href="/opinion">
#              Opinión
#             </a>
#             <ul class="dropdown">
#              <li>
#               <a href="/opinion">
#                Columnistas
#               </a>
#              </li>
#              <li>
#               <a href="/confabulario">
#                Confabulario
#               </a>
#              </li>
#              <li>
#               <a href="/el-pulso">
#                El Pulso
#               </a>
#              </li>
#              <li>
#               <a href="/trazo-del-dia">
#                Trazo del día
#               </a>
#              </li>
#              <li>
#               <a href="/dona-perla">
#                Doña Perla
#               </a>
#              </li>
#              <li>
#               <a href="/tema/ricardo-martinelli">
#                Ricardo Martinelli
#               </a>
#              </li>
#             </ul>
#             <div class="flecha-ddown">
#              <span>
#              </span>
#             </div>
#            </li>
#            <li class="menu-economia">
#             <a href="/economia">
#              Economía
#             </a>
#            </li>
#            <li class="menu-variedades">
#             <a href="/variedades">
#              Variedades
#             </a>
#            </li>
#            <li class="menu-deportes">
#             <a href="/deportes">
#              Deportes
#             </a>
#            </li>
#            <li class="menu-tecnologia">
#             <a href="/tecnologia">
#              Tecnología
#             </a>
#            </li>
#            <li class="menu-multimedia has-sub">
#             <a href="/multimedia">
#              Multimedia
#             </a>
#             <ul class="dropdown">
#              <li>
#               <a href="/videos">
#                Videos
#               </a>
#              </li>
#              <li>
#               <a href="/podcasts">
#                Podcast
#               </a>
#              </li>
#              <li>
#               <a href="/galerias">
#                Galerías
#               </a>
#              </li>
#             </ul>
#             <div class="flecha-ddown">
#              <span>
#              </span>
#             </div>
#            </li>
#            <li class="menu-especiales">
#             <a href="/trabajos-especiales">
#              Especiales
#             </a>
#            </li>
#            <li class="menu-impreso">
#             <a href="/impreso">
#              Impreso
#             </a>
#            </li>
#            <li class="menu-premium">
#             <a href="/contenido-premium">
#              Contenido Premium
#             </a>
#            </li>
#            <li class="menu-premiate">
#             <a href="https://premiate.com.pa/" rel="nofollow noopener" target="_blank">
#              <img alt="Prémiate - Club de Beneficios" data-src="/img/logo-premiate-2020.webp" style="width:initial; height:35px"/>
#             </a>
#            </li>
#            <li class="menu-507go">
#             <a aria-label="507 go" href="//507go.tv" rel="nofollow noopener" target="_blank">
#             </a>
#            </li>
#           </div>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <h1 class="header-2019-logo hide20" title="noticias de panamá">
#        <a href="/">
#         <img alt="panamá américa, noticias" height="25" src="/img/panamaamerica-logo-183.png" width="183"/>
#        </a>
#       </h1>
#       <time class="hide20-for-small-only">
#        Jueves 24 de Marzo de 2022
#       </time>
#       <a class="pa-logo-small hide21-for-small-only" href="/">
#        <img alt="Inicio" src="/img/logo-pa-white.png"/>
#       </a>
#       <div class="page-title-2018" style="display:none">
#        <h2>
#         Portada
#        </h2>
#        <style>
#         .content-sidebar-2{display:block !important}
#        </style>
#       </div>
#       <div class="menuregistro-2021">
#        <a aria-label="Membresía" class="cintillo-menbresias-d membresia-cintillo hide21-for-small-only" href="https://suscripcion.panamaamerica.com.pa/" style="background: initial !important;position:initial; margin: auto;">
#         <span style="color:#fff;font-weight:normal !Important;font-size: 13px;">
#          SUSCRÍBETE
#         </span>
#         <span style="color:#fff;font-weight:normal">
#          |
#         </span>
#        </a>
#        <div class="reg-left">
#        </div>
#        <div class="reg-center">
#        </div>
#        <div class="reg-right">
#        </div>
#       </div>
#      </div>
#      <div class="main-header-middle hide21-for-small-only">
#       <div class="header-middle-left">
#        <ul class="siguenos-en-2">
#         <li class="m-instagram">
#          <a href="https://instagram.com/panamaamerica" rel="noopener" target="_blank" title="Instagram">
#           <i class="fa fa-instagram">
#           </i>
#          </a>
#         </li>
#         <li class="icon-first m-facebook">
#          <a href="https://www.facebook.com/PanamaAmerica.com.pa" rel="noopener" target="_blank" title="facebook">
#           <i class="fa fa-facebook">
#           </i>
#          </a>
#         </li>
#         <li class="m-twitter">
#          <a href="https://twitter.com/PanamaAmerica" rel="noopener" target="_blank" title="twitter">
#           <i class="fa fa-twitter">
#           </i>
#          </a>
#         </li>
#         <li class="m-youtube">
#          <a href="https://www.youtube.com/user/diariopanamaamerica" rel="noopener" target="_blank" title="Youtube">
#           <i aria-hidden="true" class="fa fa-youtube-play">
#           </i>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="header-middle-center">
#        <a href="/" title="Ir a la portada">
#         <img alt="Panamá América" height="46" src="/img/panamaamerica-logo-345.png" width="345"/>
#        </a>
#       </div>
#       <div class="header-middle-right">
#        <div class="buscador-header-2019">
#         <form action="//www.panamaamerica.com.pa/buscador" id="search" method="get">
#          <input name="cx" type="hidden" value="006265388743205756159:y9ktgnu2wsw"/>
#          <input name="cof" type="hidden" value="FORID:11"/>
#          <input class="buscador-input-txt-2019" height="20px" id="qq" name="string" placeholder="Buscar..." size="70" type="text"/>
#          <label for="btn-cont-search">
#           <i aria-hidden="true" class="fa fa-search search-submit-btn-19x" type="">
#           </i>
#          </label>
#          <input class="btn-cont-search" id="btn-cont-search" style="display:none;" type=""/>
#         </form>
#        </div>
#       </div>
#      </div>
#      <div class="progressContainer" style="display:none">
#       <div class="progress" id="progress" style="">
#       </div>
#      </div>
#      <nav class="main-header-menu hide-on-small-only hide20-for-small-only">
#       <div class="main-header-menu-inside" style="display:flex; margin:auto">
#        <ul class="main-menu-links-2019">
#         <li>
#          <a href="/actualidad">
#           ACTUALIDAD
#          </a>
#         </li>
#         <li>
#          <a href="/opinion">
#           Opinión
#          </a>
#         </li>
#         <li>
#          <a href="/economia">
#           ECONOMía
#          </a>
#         </li>
#         <li>
#          <a href="/variedades">
#           Variedades
#          </a>
#         </li>
#         <li>
#          <a href="/deportes">
#           Deportes
#          </a>
#         </li>
#         <li>
#          <a href="/tecnologia">
#           Tecnología
#          </a>
#         </li>
#         <li>
#          <a href="/multimedia">
#           Multimedia
#          </a>
#         </li>
#         <li>
#          <a href="/impreso">
#           Impreso
#          </a>
#         </li>
#         <li class="c-premium-19" style="width:150px !important;">
#          <a href="/contenido-premium">
#           <img alt="Contenido premium" height="35" src="/img/contenido-premium-logo.webp" width="146"/>
#          </a>
#         </li>
#         <li class="hide21-for-small-only" style="padding:0 14px">
#          <a aria-label="Prémiate" href="https://premiate.com.pa/" rel="nofollow noopener" target="_blank">
#           <img alt="Prémiate" height="36" src="/img/logo-premiate-2020-blue-196.webp" style="max-width:235px !important;min-height: 35px;" width="240"/>
#          </a>
#         </li>
#         <li>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <div class="membresia-cintillo-m hide20">
#       <span>
#        <span>
#         jueves
#        </span>
#        24 de marzo de 2022
#       </span>
#       <div>
#        <img alt="Suscripción" height="23" src="/img/login/icono-membresia-70.webp?v2" width="23"/>
#        <span>
#         <a class="" href="https://suscripcion.panamaamerica.com.pa/">
#          SUSCRÍBETE
#         </a>
#        </span>
#       </div>
#      </div>
#      <nav class="menu-usuario" style="display:none">
#       <ul>
#        <li class="close-menu" onclick="toogleUserMenu()">
#         x
#        </li>
#        <li class="mi-cuenta">
#         <span>
#          Mi cuenta
#         </span>
#        </li>
#        <li>
#         <a href="//www.panamaamerica.com.pa/mi-perfil">
#          <img alt="" data-src="/img/login/iconos/miperfil.png" height="21" width="21"/>
#          <span>
#           Mi perfil
#          </span>
#         </a>
#        </li>
#        <li class="mi-membresia-li">
#        </li>
#        <li>
#         <a href="/premiate">
#          <img alt="Prémiate" height="31" src="/img/logo-premiate-2020-blue-196.webp" style="width: 48%;height: 31px !important; max-height: 31px !important;" width="90"/>
#         </a>
#        </li>
#        <li>
#         <a href="//www.panamaamerica.com.pa/mis-boletines">
#          <img alt="" data-src="/img/login/iconos/boletines.png" height="21" width="21"/>
#          <span>
#           Mis boletines
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.panamaamerica.com.pa/seguridad">
#          <img alt="" data-src="/img/login/iconos/seguridad.png" height="21" width="21"/>
#          <span>
#           Seguridad
#          </span>
#         </a>
#        </li>
#        <li class="cerrar-sesion-li last">
#        </li>
#       </ul>
#      </nav>
#      <div class="row page grid news-articles-section-wrapper">
#       <section class="main container" role="main">
#        <section class="block block-block clearfix" id="block-block-773">
#         <br/>
#        </section>
#        <section class="block block-views home-2018 home-destacadas clearfix" id="block-views-home-2018-block-23">
#         <div class="view view-home-2018- view-id-home_2018_ view-display-id-block_23 view-dom-id-4b1e15bfd1baa703ad1e073c795c5764">
#          <div class="view-header">
#           <div class="hide20-for-small-only">
#            <br/>
#           </div>
#          </div>
#          <div class="view-content l9 m12 s12 col v23">
#           <article class="panel-2018 news-article first last odd">
#            <figure class="l7 m12 col">
#             <a aria-label="" href="/judicial/tribunal-electoral-ratifica-principio-de-especialidad-de-ricardo-martinelli-1204185">
#              <img alt="" height="360" src="https://www.panamaamerica.com.pa/sites/default/files/styles/home_2018_466x300/public/imagenes/2022/03/23/magistrados-revocan-panama.jpg?itok=hlmWLcOx" width="500"/>
#              <figcaption class="resumen hide20">
#               Los magistrados indicaron que la juez de primera instancia no entró a valorar las argumentaciones, ni las pruebas planteadas por la defensa de Martinelli.
#              </figcaption>
#             </a>
#            </figure>
#            <div>
#             <h2 class="subtitulo">
#              <a href="/judicial/tribunal-electoral-ratifica-principio-de-especialidad-de-ricardo-martinelli-1204185">
#               Panamá
#              </a>
#             </h2>
#             <h3 class="l5 m12 s12 col titulo">
#              <a href="/judicial/tribunal-electoral-ratifica-principio-de-especialidad-de-ricardo-martinelli-1204185">
#               Tribunal Electoral ratifica Principio de Especialidad de Ricardo Martinelli
#              </a>
#             </h3>
#            </div>
#            <p class="l5 m5 s12 col resumen">
#             Los magistrados indicaron que la juez de primera instancia no entró a valorar las argumentaciones, ni las pruebas planteadas por la defensa de Martinelli.
#            </p>
#            <div class="l5 m5 s12 col relacionadas">
#             <div class="item-list">
#              <ul>
#               <li class="first">
#                <h3>
#                 <a href="/judicial/juzgado-ordena-liberacion-de-west-valdes-tras-permanecer-cinco-anos-detenido-1204086">
#                  Juzgado ordena liberación de West Valdés, tras permanecer cinco años detenido
#                 </a>
#                </h3>
#               </li>
#               <li class="last">
#                <h3>
#                 <a href="/judicial/tribunal-electoral-reconoce-principio-de-especialidad-ricardo-martinelli-y-mantiene-fuero">
#                  Tribunal Electoral reconoce principio de especialidad a Ricardo Martinelli y mantiene fuero penal electoral
#                 </a>
#                </h3>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </article>
#          </div>
#          <div class="baner-300x600 block-726 l3 m12 s12 col hide20-for-small-only" style="float:right;clear:none">
#           <div style="margin:0 auto; text-align:center; padding-bottom:10px">
#            <a href="https://clasificados.clasiguia.com.pa" rel="noopener" target="_blank">
#             <img alt="Clasiguía" data-src="/imagenes/clasiguiaform.jpg" height="140" width="300"/>
#            </a>
#           </div>
#           <div align="center" style="margin: 0 auto; text-align:center; align:center;">
#            <script language="JavaScript" type="text/javascript">
#             <!--
# var eplDoc = document, eplLL = false, eS1 = 'us.img.e-planning.net', eplArgs = { iIF:1,sV: schemeLocal() + "://ads.us.e-planning.net/" ,vV:"4",sI:"b7e6",kVs:{  }};
# function eplCheckStart() {
# if (document.epl) {
# var e = document.epl;
# if (e.eplReady()) return true;
# e.eplInit(eplArgs);
# if (eplArgs.custom) {
# for (var s in eplArgs.custom) {
# e.setCustomAdShow(s, eplArgs.custom[s]);
# }
# }
# return e.eplReady();
# } else if (!eplLL) {
# var epl41Script = document.createElement('SCRIPT'); epl41Script.async = true;
# epl41Script.src = schemeLocal() + '://' + eS1 + '/layers/epl-41.js';
# document.head.appendChild(epl41Script);
# eplLL = true;
# }
# return false;
# }
# eplCheckStart();
# function eplSetAd(eID) {
# var opts;
# if (eplCheckStart()) {
# if (eplArgs.sOpts && eplArgs.sOpts[eID]) {
# opts = eplArgs.sOpts[eID];
# if (opts.custF) { document.epl.setCustomAdShow(eID,opts.custF); }
# } else { opts = {}; }
# document.epl.setSpace(eID, opts);
# } else {
# setTimeout(eplSetAd.bind(null, eID), 250);
# }
# }
# function eplAD4(eID, opts) {
# document.write('<div id="eplAdDiv'+eID+'"></div>');
# if (!eplArgs.sOpts) { eplArgs.sOpts = {}; }
# eplArgs.sOpts[eID] = opts || {t:1};
# eplSetAd(eID);
# }
# function schemeLocal() {
# protocol = document.location.protocol || window.top.location.protocol;
# if (protocol) {
# return protocol.indexOf('https') !== -1 ? 'https' : 'http';
# }
# }
# //-->
#            </script>
#            <script>
#             eplAD4("934722e04c5dcbd5",{t:1,timeout:0,ma:1,custF:null,wh:"300x600",sd:"b7e6!!" + schemeLocal() + "://ads.us.e-planning.net/!!", });
#            </script>
#           </div>
#          </div>
#          <div class="view-footer l9 m12 s12 col">
#           <div class="view view-home-2018- view-id-home_2018_ view-display-id-block_24 view-dom-id-bb6b02e7c8b9b7c164f190968519a685">
#            <div class="view-content">
#             <article class="panel-2018 panel-b news-article col l3 s12 first odd">
#              <figure class="imagen col l12 s5">
#               <a aria-label="Rafael Sabonge es uno de los ministros más cuestionados por su gestión como titular del MOP. Foto: Grupo Epasa" href="/economia/panamenos-quieren-sabonge-fuera-del-mop-1204175">
#                <img alt="Rafael Sabonge es uno de los ministros más cuestionados por su gestión como titular del MOP. Foto: Grupo Epasa" data-src="/sites/default/files/styles/home_2018_302x192/public/imagenes/2022/03/24/rafael-sabonge.jpg?itok=NIg9tTH9" height="440" width="750"/>
#               </a>
#              </figure>
#              <div class="subtitulo">
#               <a href="/economia/panamenos-quieren-sabonge-fuera-del-mop-1204175">
#                Panamá
#               </a>
#              </div>
#              <h3 class="titulo col l12 s7">
#               <a href="/economia/panamenos-quieren-sabonge-fuera-del-mop-1204175">
#                Panameños quieren a Sabonge fuera del MOP
#               </a>
#              </h3>
#             </article>
#             <article class="panel-2018 panel-b news-article col l3 s12 even">
#              <figure class="imagen col l12 s5">
#               <a aria-label="Gilberto Cruz, abogado de Valdés, a su salida del Renacer tras notificarlo de su liberación. Víctor Arosemena." href="/judicial/west-valdes-recupero-su-libertad-luego-de-cinco-anos-bajo-detencion-preventiva-1204176">
#                <img alt="Gilberto Cruz, abogado de Valdés, a su salida del Renacer tras notificarlo de su liberación. Víctor Arosemena." data-src="/sites/default/files/styles/home_2018_302x192/public/imagenes/2022/03/23/west-valdes-panama.jpg?itok=cD8PPMQa" height="440" width="750"/>
#               </a>
#              </figure>
#              <div class="subtitulo">
#               <a href="/judicial/west-valdes-recupero-su-libertad-luego-de-cinco-anos-bajo-detencion-preventiva-1204176">
#                Panamá
#               </a>
#              </div>
#              <h3 class="titulo col l12 s7">
#               <a href="/judicial/west-valdes-recupero-su-libertad-luego-de-cinco-anos-bajo-detencion-preventiva-1204176">
#                West Valdés recuperó su libertad, luego de cinco años bajo detención preventiva
#               </a>
#              </h3>
#             </article>
#             <article class="panel-2018 panel-b news-article col l3 s12 odd">
#              <figure class="imagen col l12 s5">
#               <a aria-label="Jaime Alemán y Carlos Cordero de Acogal siguen dentro de juntas directivas de importantes empresas del país. Foto: Grupo Epasa" href="/judicial/aleman-y-cordero-dentro-de-directivas-de-empresas-mixtas-1204178">
#                <img alt="Jaime Alemán y Carlos Cordero de Acogal siguen dentro de juntas directivas de importantes empresas del país. Foto: Grupo Epasa" data-src="/sites/default/files/styles/home_2018_302x192/public/imagenes/2022/03/24/aleman-cordero.jpg?itok=wrSRRSs5" height="653" width="1000"/>
#               </a>
#              </figure>
#              <div class="subtitulo">
#               <a href="/judicial/aleman-y-cordero-dentro-de-directivas-de-empresas-mixtas-1204178">
#                Panamá
#               </a>
#              </div>
#              <h3 class="titulo col l12 s7">
#               <a href="/judicial/aleman-y-cordero-dentro-de-directivas-de-empresas-mixtas-1204178">
#                Alemán y Cordero dentro de directivas de empresas mixtas
#               </a>
#              </h3>
#             </article>
#             <article class="panel-2018 panel-b news-article col l3 s12 last even">
#              <figure class="imagen col l12 s5">
#               <a aria-label="West Valdés se ha mantenido cinco años detenido sin justificación. Foto: Grupo Epasa" href="/judicial/juzgado-ordena-liberacion-de-west-valdes-tras-permanecer-cinco-anos-detenido-1204086">
#                <img alt="West Valdés se ha mantenido cinco años detenido sin justificación. Foto: Grupo Epasa" data-src="/sites/default/files/styles/home_2018_302x192/public/imagenes/2022/03/23/west-valdes.jpg?itok=3vO6h9cQ" height="500" width="720"/>
#               </a>
#              </figure>
#              <div class="subtitulo">
#               <a href="/judicial/juzgado-ordena-liberacion-de-west-valdes-tras-permanecer-cinco-anos-detenido-1204086">
#                Panamá
#               </a>
#              </div>
#              <h3 class="titulo col l12 s7">
#               <a href="/judicial/juzgado-ordena-liberacion-de-west-valdes-tras-permanecer-cinco-anos-detenido-1204086">
#                Juzgado ordena liberación de West Valdés, tras permanecer cinco años detenido
#               </a>
#              </h3>
#             </article>
#            </div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <section class="block block-views home-2018 home-destacadas clearfix" id="block-views-home-2018-block-21">
#         <div class="view view-home-2018- view-id-home_2018_ view-display-id-block_21 view-dom-id-0ede37168644b4fbaedc4fc6ec3305b5">
#          <div class="view-content l6 m6 col">
#           <article class="panel-2018 first last odd">
#            <span class="subtitulo hide20">
#             Estados Unidos
#            </span>
#            <h3 class="titulo">
#             <a href="/mundo/rusia-fracasa-en-la-onu-con-su-resolucion-humanitaria-sobre-ucrania-1204173">
#              Rusia fracasa en la ONU con su resolución humanitaria sobre Ucrania
#             </a>
#            </h3>
#            <figure>
#             <a href="/mundo/rusia-fracasa-en-la-onu-con-su-resolucion-humanitaria-sobre-ucrania-1204173">
#              <img alt="El embajador ruso ante la ONU, Vasili Nebenzia, se dirige a la Asamblea General de la ONU, en la sede de Naciones Unidas, en Nueva York (EE.UU.), este 23 de marzo de 2022. Foto: EFE" height="412" src="https://www.panamaamerica.com.pa/sites/default/files/styles/home_2018_640x412/public/imagenes/2022/03/23/vasili-nebenzia.jpg?itok=NpdWs2Vd" title="El embajador ruso ante la ONU, Vasili Nebenzia, se dirige a la Asamblea General de la ONU, en la sede de Naciones Unidas, en Nueva York (EE.UU.), este 23 de marzo de 2022. Foto: EFE" width="640"/>
#             </a>
#            </figure>
#            <p class="resumen">
# ...
#                  </a>
#                 </li>
#                </ul>
#                <div class="lab-content">
#                 <span class="dash">
#                  <a href="/contenido-premium" title="Contenido Premium">
#                   <img alt="Contenido premium" data-src="/imagenes/cont_premium.webp" height="42" width="159"/>
#                  </a>
#                 </span>
#                </div>
#               </div>
#               <div class="col l3 m3 l-left">
#                <div>
#                 <a href="https://registro.panamaamerica.com.pa/login/inscribete.php" rel="noopener" target="_blank">
#                  Regístrate
#                 </a>
#                </div>
#                <div>
#                 <a href="/registro/login">
#                  Inicia sesión
#                 </a>
#                </div>
#                <div>
#                 <a href="/impreso">
#                  Impreso
#                 </a>
#                </div>
#               </div>
#               <div class="col l4 m4 s12">
#                <div class="row">
#                 <div class="col l6 m6 s6">
#                  <div>
#                   <a href="//www.panamaamerica.com.pa">
#                    Panamá América
#                   </a>
#                  </div>
#                  <div>
#                   <a href="//www.critica.com.pa" rel="noopener" target="_blank">
#                    Crítica
#                   </a>
#                  </div>
#                  <div>
#                   <a href="//www.diaadia.com.pa" rel="noopener" target="_blank">
#                    Día a Día
#                   </a>
#                  </div>
#                  <div>
#                   <a href="//www.mujer.com.pa" rel="noopener" target="_blank">
#                    Mujer
#                   </a>
#                  </div>
#                  <div>
#                   <a href="http://recetas.com.pa" rel="noopener" target="_blank">
#                    Recetas
#                   </a>
#                  </div>
#                 </div>
#                 <div class="col l6 m6 s6">
#                  <div>
#                   <a href="//impresos.epasa.com.pa" rel="noopener" target="_blank">
#                    Impresos
#                   </a>
#                  </div>
#                  <div>
#                   <a href="//www.cine.com.pa" rel="noopener" target="_blank">
#                    Cine
#                   </a>
#                  </div>
#                  <div>
#                   <a href="//www.clasiguia.com.pa" rel="noopener" target="_blank">
#                    Clasiguía
#                   </a>
#                  </div>
#                  <div>
#                   <a href="//premiate.com.pa" rel="noopener" target="_blank">
#                    Prémiate
#                   </a>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <ul class="col l4 m4 s12 footer-menu" style="display:flex; flex-wrap:wrap; margin:7px auto 20px auto">
#                <li>
#                 <div>
#                  <a href="https://www.panamaamerica.com.pa/actualidad">
#                   Noticias
#                  </a>
#                 </div>
#                </li>
#                <li>
#                 <div>
#                  <a href="https://www.panamaamerica.com.pa/videos">
#                   Videos
#                  </a>
#                 </div>
#                </li>
#                <li>
#                 <div>
#                  <a href="https://www.panamaamerica.com.pa/tema/exclusivo-web">
#                   Exclusivo Web
#                  </a>
#                 </div>
#                </li>
#                <li>
#                 <div>
#                  <a href="https://www.panamaamerica.com.pa/opinion">
#                   Columnas
#                  </a>
#                 </div>
#                </li>
#               </ul>
#               <div class="col l2 m2" style="padding-left: 15px;">
#                <div class="row">
#                 <div class="large-12 medium-12 columns" style="padding-left: 50px;">
#                  <p class="diario-asociados">
#                   Miembro de:
#                  </p>
#                  <img alt="Miembro del PAL" data-src="/img/logo-PAL.webp?dmmdmd" height="50" width="98"/>
#                  <div style="margin-top: 15px;">
#                  </div>
#                  <img alt="Sociedad de prensa" data-src="/img/logo-sociedad-prensa.webp" height="47" width="135"/>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="red-line">
#             </div>
#             <div class="container">
#              <div class="row texto" style="text-align:center">
#               <div class="col l12">
#                <p class="center-align">
#                 Todos los derechos reservados Editora Panamá América S.A. - Ciudad de Panamá - Panamá 2022.
#                </p>
#                <p class="center-align">
#                 Prohibida su reproducción total o parcial, sin autorización escrita de su titular.
#                </p>
#               </div>
#              </div>
#             </div>
#            </div>
#           </footer>
#           <div class="cookies">
#            <div class="chip">
#             <span>
#              Utilizamos cookies propias y de terceros para mejorar nuestros servicios y mostrarle publicidad relacionada con sus preferencias mediante el análisis de sus hábitos de navegación. Si continua navegando, consideramos que acepta su uso. Puede cambiar la configuración u obtener más información
#              <a href="/politicas-de-cookies">
#               "aquí"
#              </a>
#              .
#             </span>
#             <i class="fa fa-close close material-icons">
#             </i>
#            </div>
#           </div>
#          </section>
#          <section class="block block-block clearfix" id="block-block-438">
#           <div class="contenidomodal-2018">
#           </div>
#           <div class="cajavacia-2018">
#           </div>
#           <script>
#            var cajavacia = document.querySelector('.cajavacia-2018'); window.addEventListener("message", respuesta, false);var res;function respuesta (event) {if(event.data=="crearcuenta"){desbloquearPantalla();mostrarCrearCuenta();}if(event.data=="iniciarsesion"){desbloquearPantalla();mostrarIniciarSesion();}if(event.data=="cerrarmodal"){desbloquearPantalla();}if(event.data=="quitarperfil"){window.location.href="/";return;}if(event.data=="crear450"){jQuery(".mostrar-modal.modal-crear").addClass("crear450");}if(event.data=="returnToHome"){window.location.href = "/";}if(event.data=="cfUpdated"){if(typeof(paywall) !==undefined){paywall.signOff();}document.cookie = "gtx8id=null;expires=Thu, 01 Jan 1970 00:00:00 GMT;path=/";window.location.href = "/";}} jQuery(".cajavacia-2018").click(function() {    ocultarCrearCuenta();});function revisarPremium(){if(jQuery("article.nota-premium").length >0){bloquearArticulo();}}function bloquearArticulo(){if (typeof(jQuery(".nota-restriccion-msg").html()) === "undefined"){jQuery(".notas-body .robapagina-centreado").remove();jQuery("#comments18-wrapper").remove();jQuery("#share-comments").remove();jQuery(".view-las-mas-leidas-nueva").remove();jQuery("#taboola-below-homepage-thumbnails").remove();jQuery("#block-block-534").remove();jQuery("#block-block-683").remove();jQuery(".reacciones").remove();jQuery("#pocoton-products").remove();if(jQuery(".notas-body .notas > div >*:nth-child(1)").text().trim().length < 80){jQuery(".notas-body .notas > div >*:nth-child(n+3)").remove();}else jQuery(".notas-body .notas > div >*:nth-child(n+2)").remove(); jQuery(".notas-body .notas > div >*:nth-child(1)").css({"height": "140px", "overflow": "hidden"});jQuery(".notas-body .notas > div >*").wrapAll('<div class="preview-premium"></div>');jQuery(".preview-premium").append('<div class="preview-premium-sombra"></div>');jQuery(".notas-body").append('<div class="nota-restriccion-msg"><div class="restriccion-header"><div></div><span><img class="bloqueo-star-w" src="/img/star-blanca35.png"></span><div></div></div><div class="restriccion-title">Inicia sesión para seguir leyendo</div><div class="restriccion-desc">Solo con tener una cuenta ya puedes leer este artículo, es GRATIS.</div><div class="restriccion-btns-registro"><span class="registrate-aqui-btn-new">Regístrate</span><span class="inicia-ses-btn-new">Ingresar</span></div><div class="restriccion-footer">Gracias por leer <b>Panamá América</b></div></div>');jQuery(".registrate-aqui-btn-new").on("click",function() {mostrarCrearCuenta();});jQuery(".inicia-ses-btn-new").on("click",function() {mostrarIniciarSesion();});}}function mostrarLoader(){return;}function mostrarCrearCuenta(){let isPremium;if(document.getElementsByClassName("nota-premium")[0] !== undefined){isPremium = true;}else{isPremium = false;}window.location.href= '/registro/crear?next='+ btoa(document.URL) +'&pr='+isPremium;return;desbloquearPantalla();bloquearPantalla();mostrarLoader();jQuery('.contenidomodal-2018').addClass('mostrar');jQuery('.contenidomodal-2018').addClass('mostrar-modal');jQuery('.contenidomodal-2018').addClass('modal-crear');let w = screen.width;jQuery('.contenidomodal-2018').append('<if'+'rame src="//registro.panamaamerica.com.pa/login/logintest.php?crear&w='+w+'&nodeid&sname=panamaamericacompa&nodeid=front18&ruta=//www.panamaamerica.com.pa&path=/&pr='+isPremium+'&"></if'+'rame>');}function mostrarIniciarSesion(){let isPremium;if(document.getElementsByClassName("nota-premium")[0] !== undefined){isPremium = true;}else{isPremium = false;}window.location.href= '/registro/login?next='+ btoa(document.URL.split('?')[0]) +'&pr='+isPremium;return;let w = screen.width;bloquearPantalla();mostrarLoader();jQuery('.contenidomodal-2018').addClass('mostrar');jQuery('.contenidomodal-2018').addClass('mostrar-modal');jQuery('.contenidomodal-2018').addClass('modal-login');jQuery('.contenidomodal-2018').append('<if'+'rame src="//registro.panamaamerica.com.pa/login/logintest.php?login&w='+w+'&nodeid&sname ...
#           </script>
#          </section>
#          <section class="block block-block clearfix" id="block-block-785">
#           <div id="div-publicidade-fixorodape" style="width: 100%; bottom: 0; z-index: 999; position: fixed; left:0; right:0;">
#            <script>
#             <!--//--><![CDATA[// ><!--
# googletag.cmd.push(function () {
# googletag.display("div-publicidade-fixorodape");
# });
# //--><!]]>
#            </script>
#           </div>
#          </section>
#         </div>
#         <div class="footer-copyright">
#         </div>
#        </footer>
#       </section>
#      </div>
#      <script async="async" src="/sites/all/themes/panamaamerica_materialize/js/custom-ser.js?55s5sccc3">
#      </script>
#      <link as="style" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css?display=swap" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#      <noscript>
#       <link href="https://fonts.googleapis.com/css?family=Montserrat&amp;display=swap" rel="stylesheet" type="text/css"/>
#      </noscript>
#      <link href="/sites/all/themes/panamaamerica_materialize/css/swiper.min.css" rel="stylesheet"/>
#      <script src="/sites/all/themes/panamaamerica_materialize/js/swiper.min.js">
#      </script>
#      <script>
#       document.querySelector('.home-pa-videos .view-content').classList.add('swiper-wrapper');
# document.querySelector('.home-pa-contenido-premium .view-content').classList.add('swiper-wrapper');
# if(document.querySelector('.home-pma-decide .view-content') != null)
# document.querySelector('.home-pma-decide .view-content').classList.add('swiper-wrapper');
# var slidesPerView = "auto";
# var spaceBetween = 10;
# var swiper = new Swiper('.home-pa-videos .view, .home-pa-covid .view, .home-pa-exclusivo .view, .home-pa-contenido-premium, .home-pma-decide .view', {
# slidesPerView: slidesPerView,
# spaceBetween: spaceBetween,
# freeMode: true,
# lazy: true
# });
# function plusDivs(n) {
# showDivs(slideIndex += n);
# }
# function showDivs(n) {
# var i;
# var x = document.getElementsByClassName("mySlides");
# if (n > x.length) {slideIndex = 1}
# if (n < 1) {slideIndex = x.length} ;
# for (i = 0; i < x.length; i++) {
# x[i].style.visibility = "hidden";
# }
# x[slideIndex-1].style.visibility = "visible";
# }
# var slideIndex = 1;
# //showDivs(slideIndex);
#      </script>
#      <style>
#       body>span>img {
# width: initial;
# }
# .view-id-home_2018_.view-display-id-block_18 .view-content{
# position: relative;
# height: 216px;
# overflow:hidden;
# }
# .view-id-home_2018_.view-display-id-block_18 .view-content .mySlides{
# visibility:hidden;
# position:absolute;
# height: 216px;
# }
# .view-id-home_2018_.view-display-id-block_18 .view-content .mySlides:nth-child(1){
# visibility:visible;
# }
# @media screen and (max-width: 800px) {
# .view-id-home_2018_.view-display-id-block_18 .view-content{
# position: relative;
# height: 916px;
# overflow:hidden;
# }
# .view-id-home_2018_.view-display-id-block_18 .view-content .mySlides{
# visibility:hidden;
# position:absolute;
# height: 916px;
# }
# }
#      </style>
#      <link as="style" href="/sites/all/themes/mobilepa2016/css/registro.css?v5" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#      <noscript>
#       <link href="/sites/all/themes/mobilepa2016/css/registro.css?v4" media="all" rel="stylesheet" type="text/css"/>
#      </noscript>
#      <script>
#       !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window,document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '1993521960918834');
# fbq('track', 'PageView');
#      </script>
#      <noscript>
#       <img alt="" height="1" src="https://www.facebook.com/tr?id=1993521960918834&amp;ev=PageView&amp;noscript=1" style="height:1px !important; width:1px !important;" width="1"/>
#      </noscript>
#      <div id="ads_9BWEJN40YOG8">
#      </div>
#      <script language="javascript" type="text/javascript">
#       (function(){
# var newscript= document.createElement('script');
# newscript.type = 'text/javascript';
# newscript.async = true;
# lz_elem = (document.getElementsByTagName('head')[0]||document.getElementsByTagName('body')[0]);
# lz_elem.appendChild(newscript);
# newscript.onload = function(ev){
# var lz_url="https://play.sunmediaads.com/red/zone.php?code=9BWEJN40YOG8&a=&pubid=&lgid="+((new Date()).getTime() % 2147483648) + Math.random();
# var lz_target = "ads_9BWEJN40YOG8";
# var lz_sync_mode=false;
# lz_loadads(lz_url ,lz_target,lz_sync_mode);
# }
# newscript.src= "https://img.sunmediaads.com/ads/lz_loader.js?ver=1.4";
# })();
#      </script>
#      <script>
#       function a(r){try{for(;r.parent&&r!==r.parent;)r=r.parent;return r}catch(r){return null}}var n=a(window);if(n&&n.document&&n.document.body){var s=document.createElement("script");s.src="https://static.sunmedia.tv/integrations/36a67915-2d1d-4e81-9e13-f35c23133487/36a67915-2d1d-4e81-9e13-f35c23133487.js",s.async=!0,n.document.body.appendChild(s)}
#      </script>
#      <script>
#       if(panamaamerica.device =="desktop"){
# var vidoomy= document.createElement('script');
# vidoomy.src = 'https://ads.vidoomy.com/panamaamericacompa_1028.js';
# vidoomy.rel = 'text/javascript';
# vidoomy.async = 'async';
# document.getElementsByTagName('head')[0].appendChild(vidoomy);
# }
#      </script>
#      <style>
#       .scrolly .premiatecintillo{
# display:none !important;
# }
# .bloquear-pag{
# overflow:hidden;
# }
# .main.container > .google-auto-placed, #page> .google-auto-placed{
# transform: scale(.88);
# margin-top: -10px;
# padding-bottom:15px;
# }
#      </style>
#      <script crossorigin="anonymous" data-cf-beacon='{"rayId":"6f0fd32f6a098dd2","token":"9fce0dca25484fd7841c5d204350a792","version":"2021.12.0","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194">
#      </script>
#     </div>
#    </header>
#   </div>
#  </body>
# </html>

# %%
nav_soup = home_soup.find('ul', attrs={'class':'main-menu-links-2019'}).find_all('li')[:-3]
nav = [sec.a.get('href') for sec in nav_soup]
nav
# Out:
# ['/actualidad',
#  '/opinion',
#  '/economia',
#  '/variedades',
#  '/deportes',
#  '/tecnologia',
#  '/multimedia',
#  '/impreso']

# %%
sec_url = HOME_URL + nav[2]

economia_response = requests.get(sec_url)
economia_soup = BeautifulSoup(economia_response.content, 'lxml')
print(economia_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="160647454000723" property="fb:pages"/>
#   <title>
#    Economía | Panamá América
#   </title>
#   <link as="style" href="/sites/all/themes/panamaamerica_materialize/css/materialize-cols-min.css" rel="preload"/>
#   <link as="style" href="/sites/all/themes/panamaamerica_materialize/css/custom.css?45" rel="preload"/>
#   <link as="script" href="https://www.panamaamerica.com.pa/sites/default/files/js/js_38VWQ3jjQx0wRFj7gkntZr077GgJoGn5nv3v05IeLLo.js" rel="preload"/>
#   <link as="script" href="https://www.panamaamerica.com.pa/sites/default/files/js/js_KqhyK1UJp8ny-5ZZVLo14BE1BFMvBVOI2dYTTz-B0dw.js" rel="preload"/>
#   <link href="https://cdn.lavoz.com.ar" rel="preconnect"/>
#   <meta content="Panamá América" property="og:site_name"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://www.panamaamerica.com.pa/economia" property="og:url"/>
#   <meta content="Economía" property="og:title"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="https://www.panamaamerica.com.pa/economia" name="twitter:url"/>
#   <meta content="Panamá América" name="twitter:title"/>
#   <meta content="Noticias de Panamá y el mundo" name="twitter:description"/>
#   <link href="/img/apple-touch-icon-iphone-60x60.png" rel="apple-touch-icon"/>
#   <link href="/img/apple-touch-icon-ipad-76x76.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/img/apple-touch-icon-iphone-retina-120x120.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/img/apple-touch-icon-ipad-retina-152x152.png" rel="apple-touch-icon" sizes="144x144"/>
#   <meta content="2f13e663f124tajn2emw5q6t9dc6sp" name="facebook-domain-verification"/>
#   <meta content="Noticias de Economia en Panamá América." name="description"/>
#   <meta content="Noticias de Economia en Panamá América." name="og:description"/>
#   <meta content="https://www.panamaamerica.com.pa/img/panamaamerica-horizontal.jpg" property="image"/>
#   <meta content="https://www.panamaamerica.com.pa/img/panamaamerica-horizontal.jpg" property="og:image"/>
#   <meta content="Economia, noticias de Economia, panamaamerica.com.pa, información, periodico, el panamaamerica" name="keywords"/>
#   <meta content="News" name="genre"/>
#   <meta content="Panamá América" name="author"/>
#   <meta content="Panama" name="geo.placename"/>
#   <meta content="es" name="language"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="https://www.panamaamerica.com.pa/rss/economia" rel="alternate" type="application/rss+xml"/>
#   <script type="application/ld+json">
#    [
# {
# "@context": "https://schema.org",
# "@type": "Organization",
# "name": "Panamá América",
# "url": "https://www.panamaamerica.com.pa",
# "sameAs": [
# "https://www.panamaamerica.com.pa/rss/recent/index.xml",
# "https://www.instagram.com/panamaamerica/",
# "https://www.facebook.com/PanamaAmerica.com.pa",
# "https://twitter.com/PanamaAmerica",
# "https://www.youtube.com/user/diariopanamaamerica"
# ],
# "potentialAction": {
# "@type": "SearchAction",
# "target": "https://www.panamaamerica.com.pa/buscador?string={search_term_string}",
# "query-input": "required name=search_term_string"
# },
# "logo": {
# "@context": "http://schema.org",
# "@type": "ImageObject",
# "url": "https://panamaamerica.com.pa/img/panamaamerica-horizontal.jpg",
# "width": "800",
# "height": "600"
# }
# },
# {
# "@context": "http://schema.org",
# "@type": "WebSite",
# "name": "Panamá América",
# "url": "https://www.panamaamerica.com.pa",
# "sameAs": [
# "https://www.panamaamerica.com.pa/rss/recent/index.xml",
# "https://www.instagram.com/panamaamerica/",
# "https://www.facebook.com/PanamaAmerica.com.pa",
# "https://twitter.com/PanamaAmerica",
# "https://www.youtube.com/user/diariopanamaamerica"
# ]
# }
# ]
#   </script>
#   <link href="https://www.panamaamerica.com.pa/economia" rel="canonical"/>
#   <link href="/sites/all/themes/panamaamerica_materialize/css/materialize-cols-min.css?v3" media="all" rel="stylesheet" type="text/css"/>
#   <meta content="0" name="node-count"/>
#   <link href="https://www.panamaamerica.com.pa/img/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://www.panamaamerica.com.pa/img/favicon.png" rel="shortcut icon" type="image/png"/>
#   <link href="/sites/all/themes/panamaamerica_materialize/css/custom.css?g2f25353h232s" rel="stylesheet" type="text/css"/>
#   <link as="style" href="https://fonts.googleapis.com/css?family=Montserrat&amp;display=swap" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#   <script>
#    const panamaamerica = JSON.parse('{"url":"\/\/www.panamaamerica.com.pa","path":"\/economia","contentType":"page","paywallUrl":"https:\/\/suscripcion.panamaamerica.com.pa","paywallType":"free_access","isPremium":false,"category":null,"allowedContentTypes":["article","video","galeria"],"params":{"registro":false,"login":""}}');const device = screen.width;panamaamerica.device = (device<800) ? 'mobile':'desktop';window.paywallConfig = {paywallUrl:panamaamerica.paywallUrl,async: true,type: panamaamerica.paywallType,contentType: panamaamerica.contentType,cookieDomain: '.panamaamerica.com.pa', debug: false,loginwallLimit: panamaamerica.isPremium ? 0 : 9999999 , paywallLimit: 9999999, category: panamaamerica.category,allowedContentTypes: panamaamerica.allowedContentTypes};     window.paywall = window.paywall || {};    paywall.queue = window.paywall.queue || [];        (async () => {const user = await getUser();if(user !== null){ paywall.queue.push(['invoke', 'signIn', {id: user.id,email: user.email,first_name: user.first_name,last_name: user.last_name,avatar: null,gender: user.gender,age: user.age,phone: user.phone,tipo_doc: user.tipo_doc,num_doc: user.num_doc,roles: user.roles}]);}else{try{paywall.signOff();}catch (e){console.log(e);}}paywall.queue.push(['addEventListener', 'loginwall', function (event) {if(panamaamerica.isPremium === true){bloquearArticulo();}}]); paywall.queue.push(['invoke', 'check']);crearMenu(user);if(panamaamerica.params.login){mostrarIniciarSesion();}if(panamaamerica.params.registro){mostrarCrearCuenta();}enviarDatosGa(user);    })();function enviarDatosGa(user){const upUrl = new URL( document.URL.split('?')[0] );var send = false;if( panamaamerica.isPremium ){upUrl.searchParams.set('cc', 'true');send = true;}if(user){upUrl.searchParams.set('lg', 'true');send = true;}console.log('%c upUrl ==============> '+ upUrl.href, "color: blue");  }function crearMenu(user){let oldReg = document.querySelector('.menuregistro');if(oldReg != null) oldReg.outerHTML="";var menuRegistro = document.querySelector('.menuregistro-2021');if(menuRegistro != null) menuRegistro.style.display="flex";if(user === null){  if(document.cookie.split("gtx8id")[1]!==undefined){document.cookie = "gtx8id=null;expires=Thu, 01 Jan 1970 00:00:00 GMT;path=/";}if(panamaamerica.device == "desktop"){menuRegistro.querySelector('.reg-left').innerHTML ='<img src="https://www.panamaamerica.com.pa/img/login/user_male_w.png" width="25" height="25" alt>';menuRegistro.querySelector('.reg-center').innerHTML ='<span onclick="mostrarIniciarSesion()">Ingresar</span>';}else{menuRegistro.querySelector('.reg-center').innerHTML = '<img src="/img/login/user_male_off_2_azul.webp" width="30" height="30" alt="Iniciar Sesión o Crear Cuenta">';menuRegistro.setAttribute('onclick', 'mostrarIniciarSesion()');}}else{setUserData(user.id, user.name, user.email);document.querySelector('.mi-membresia-li').innerHTML ='<a href="https://suscripcion.panamaamerica.com.pa/mi-suscripcion" target="_blank" rel="nofollow noopener"><img src="/img/login/iconos/membresia.png" alt><span>Mi suscripción</span></a>';document.querySelector('.cerrar-sesion-li').innerHTML ='<a href="//registro.panamaamerica.com.pa/login/logout.php?referido=//www.panamaamerica.com.pa" rel="nofollow"><img src="/img/login/iconos/salir.png" alt><span>Cerrar sesión</span></a>';if(panamaamerica.device == "desktop"){menuRegistro.querySelector('.reg-left').innerHTML ='<img src="/img/login/user_male_online.png" width="25" height="25" alt>';menuRegistro.querySelector('.reg-center').innerHTML ='<span onclick="toogleUserMenu()">'+ user.first_name.split(' ')[0] +'</span>';menuRegistro.querySelector('.reg-right').innerHTML ='<div onclick="toogleUserMenu()"></div>';}else{menuRegistro.querySelector('.reg-center').innerHTML = '<img src="/img/login/user_male_online_2_verde_4.png?123" width="30" height="30" alt="Registro">';document.querySelector('.reg-center').setAttribute('onclick', 'toogleUserMenu()');}}}async function getUser() {con ...
#   </script>
#   <script src="//code.jquery.com/jquery-3.1.1.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# window.jQuery || document.write("<script src='/sites/all/modules/jquery_update/replace/jquery/3.1/jquery.min.js'>\x3C/script>")
# //--><!]]>
#   </script>
#   <script src="https://www.panamaamerica.com.pa/sites/default/files/js/js_38VWQ3jjQx0wRFj7gkntZr077GgJoGn5nv3v05IeLLo.js" type="text/javascript">
#   </script>
#   <script src="https://www.panamaamerica.com.pa/sites/default/files/js/js_KqhyK1UJp8ny-5ZZVLo14BE1BFMvBVOI2dYTTz-B0dw.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# (function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","https://www.google-analytics.com/analytics.js","ga");ga("create", "UA-1122582-1", {"cookieDomain":".panamaamerica.com.pa"});ga("send", "pageview");
# //--><!]]>
#   </script>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"panamaamerica_materialize","theme_token":"mMQN07vVpVkCN-6T5X_r_09h2tQL2SHvXeOIqdWrb24","js":{"\/\/code.jquery.com\/jquery-3.1.1.min.js":1,"0":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"public:\/\/languages\/es_ENITyuaOjDjrnwcGXmpoOAwgoLmMLYIE2P9TxYKk6kI.js":1,"sites\/all\/modules\/google_analytics\/googleanalytics.js":1,"1":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"sites\/all\/modules\/date\/date_api\/date.css":1,"sites\/all\/modules\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"modules\/poll\/poll.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/views\/css\/views.css":1,"sites\/all\/modules\/ctools\/css\/ctools.css":1,"sites\/all\/themes\/panamaamerica_materialize\/css\/style.css":1,"sites\/all\/themes\/panamaamerica_materialize\/css\/materialize.min.css":1}},"googleanalytics":{"trackOutbound":1,"trackMailto":1,"trackDownload":1,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip","trackDomainMode":1}});
# //--><!]]>
#   </script>
#   <script type="text/javascript">
#    function readCookie(name) {
# var nameEQ = name + "=";
# var ca = document.cookie.split(';');
# for(var i=0;i < ca.length;i++) {
# var c = ca[i];
# while (c.charAt(0)==' ') c = c.substring(1,c.length);
# if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length,c.length);
# }
# return null;
# }
# function getExternalUserId()
# {
# var usermailfinal = localStorage.getItem("paregmailuser");
# if (typeof usermailfinal !== "undefined" && usermailfinal != null)
# return atob(usermailfinal);
# else return;
# };
#   </script>
#   <script src="https://scdn.cxense.com/cx.js" type="text/javascript">
#   </script>
#   <script>
#    var cX = cX || {}; cX.callQueue = cX.callQueue || [];
# cX.callQueue.push(['setSiteId', '1139591241309920180' ]);
# cX.callQueue.push(['cint', '200']);
# cX.callQueue.push(['invoke', function() {
# var cookieValue = cX.getUserSegmentIds({persistedQueryId:'14579d7bfbef7ecfaa2e4f59148bd4977cc26d2c'}).join('|');
# var expireDate = new Date(new Date().getTime() + 180 * 1000 * 60 * 60 * 24).toGMTString();
# document.cookie = 'cxSegmentos=' + cookieValue + ';expires=' + expireDate + ';path=/';}
# ]);
# var externalUserId = getExternalUserId();
# if (typeof externalUserId !== "undefined" && externalUserId != null) {
# cX.callQueue.push(["addExternalId", {"id": externalUserId,"type":"epa"}]);
# }
# cX.callQueue.push(['sendPageViewEvent']);
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PFPDQDP');
#   </script>
#   <script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# googletag.cmd.push(function () {
# var REFRESH_KEY = "refresh";
# var REFRESH_VALUE = "true";
# var mapping1 =
# googletag.sizeMapping()
# .addSize([980, 200], [[970, 90],[728, 90],[970, 250],])
# .addSize([640, 200], [[336, 280],[300, 250],[320, 50],[320, 100],[300, 50],[300, 100],[468, 60],[300, 600],])
# .addSize([336, 200], [[336, 280],[300, 250],[320, 50],[320, 100],[300, 50],[300, 100],[300, 600],])
# .addSize([0, 0], [])
# .build();
# var mapping2 =
# googletag.sizeMapping()
# .addSize([300, 50], [[300, 250],[320, 50],[300, 50],[300, 100],])
# .build();
# var mappingFixed =
# googletag.sizeMapping()
# .addSize([980, 200], [[728, 90]])
# .addSize([640, 200], [[240, 50],[240, 100],[320, 50],[320, 100],[300, 50],[320, 50]])
# .addSize([336, 200], [[240, 50],[240, 100],[320, 50],[320, 100],[300, 50],[320, 50]])
# .addSize([0, 0], [])
# .build();
# var sidebar =
# googletag.sizeMapping()
# .addSize([300, 50], [[300, 250],[320, 50],[300, 50],[300, 100],[336, 280],[320, 50],[320, 100],])
# .build();
# //start slot declaration
# googletag.defineSlot('/1056710/pa-top-1', [[970, 250], [950, 90], [930, 180], [710, 90], [970, 66], [980, 120], [728, 180], [750, 200], [630, 80], [468, 60], [980, 90], [750, 100], [960, 90], [728, 90], [970, 90]], 'div-gpt-ad-1642447218029-0')
# .defineSizeMapping(mapping1)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio3_728x90_970x90_DT', [[468, 60], [300, 250], [300, 100], [728, 90], [320, 100], [300, 50], [336, 280], [320, 50], [970, 250], [970, 90], [300, 600]], 'div-gpt-ad-1636993452963-0')
# .defineSizeMapping(mapping1)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio4_728x90_970x90_DT', [[300, 50], [300, 600], [300, 100], [728, 90], [320, 100], [970, 90], [320, 50], [468, 60], [970, 250], [300, 250], [336, 280]], 'div-gpt-ad-1636994012933-0')
# .defineSizeMapping(mapping1)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio5_728x90_970x90_DT', [[468, 60], [300, 250], [970, 250], [970, 90], [300, 100], [320, 100], [300, 50], [728, 90], [320, 50], [300, 600], [336, 280]], 'div-gpt-ad-1636994317563-0')
# .defineSizeMapping(mapping1)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio6_728x90_970x90_DT', [[320, 100], [320, 50], [300, 600], [970, 250], [728, 90], [336, 280], [300, 250], [468, 60], [970, 90], [300, 100], [300, 50]], 'div-gpt-ad-1636994366268-0')
# .defineSizeMapping(mapping1)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio7_728x90_970x90_DT', [[300, 250], [300, 100], [728, 90], [320, 100], [300, 50], [336, 280], [970, 250], [970, 90], [320, 50], [468, 60], [300, 600]], 'div-gpt-ad-1636994478811-0')
# .defineSizeMapping(mapping1)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio8_728x90_970x90_DT', [[300, 250], [970, 250], [336, 280], [970, 90], [320, 50], [468, 60], [300, 600], [320, 100], [728, 90], [300, 50], [300, 100]], 'div-gpt-ad-1636994530744-0')
# .defineSizeMapping(mapping1)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio13_300x250_300x50_300x100_DT', [[300, 100], [300, 50], [300, 250]], 'div-gpt-ad-1636995632841-0')
# .defineSizeMapping(mapping2)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# //PARA SIDEBAR 3 bloques
# googletag.defineSlot('/1056710/espacio1_300x250_336x280_DT', [[300, 50], [300, 100], [320, 50], [320, 100], [300, 250], [336, 280]], 'div-gpt-ad-1636994881199-0')
# .defineSizeMapping(sidebar)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio2_300x250_336x280_DT', [[300, 250], [336, 280], [320, 50], [320, 100], [300, 50], [300, 100]], 'div-gpt-ad-1636994889452-0')
# .defineSizeMapping(sidebar)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/espacio16_300x250_336x280_DT', [[320, 100], [728, 90], [320, 50], [300, 600], [970, 250], [336, 280], [300, 250], [468, 60], [970, 90], [300, 100], [300, 50]], 'div-gpt-ad-1639162125989-0')
# .defineSizeMapping(sidebar)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# //fixed abajo de pagina
# googletag.defineSlot('/1056710/espacio15_300x250_336x280_DT', [[300, 250], [970, 250], [336, 280], [970, 90], [320, 50], [468, 60], [300, 600], [320, 100], [728, 90], [300, 50], [300, 100]], 'div-publicidade-fixorodape')
# .defineSizeMapping(mappingFixed)
# .setTargeting(REFRESH_KEY, REFRESH_VALUE)
# .setTargeting("refreshed_slot", "false")
# .addService(googletag.pubads());
# googletag.defineSlot('/1056710/EspacioIntersticial1', [1, 1], 'div-gpt-ad-1639162438050-0').addService(googletag.pubads());
# //end slot declaration
# //Start refresh
# //developer docs: https://developers.google.com/doubleclick-gpt/guides/control-ad-loading
# var SECONDS_TO_WAIT_AFTER_VIEWABILITY = 30;
# googletag
# .pubads()
# .addEventListener("impressionViewable", function (event) {
# var slot = event.slot;
# if (slot.getTargeting(REFRESH_KEY).indexOf(REFRESH_VALUE) > -1) {
# setTimeout(function () {
# if (slot.getTargeting("refreshed_slot")) {
# slot.setTargeting("refreshed_slot", "true");
# }
# googletag.pubads().refresh([slot]);
# }, SECONDS_TO_WAIT_AFTER_VIEWABILITY * 1000);
# }
# });
# //End refresh
# //Start Lazy Load
# //developer docs: https://developers.google.com/doubleclick-gpt/samples/lazy-loading
# googletag.pubads().enableLazyLoad({
# fetchMarginPercent: 200,
# renderMarginPercent: 200,
# mobileScaling: 2.0,
# });
# //End lazy load
# //key values segmentation
# //developer docs: https://developers.google.com/doubleclick-gpt/guides/key-value-targeting
# googletag.pubads().setTargeting("categoria", ["economy","world","sports"]);
# googletag.pubads().setTargeting("tags", ["dolar", "futbol", "dog"]);
# googletag.pubads().setTargeting("idArticle", ["1234567"]);
# //googletag.pubads().enableSingleRequest(); //with this line active, lazy load won't work
# googletag.pubads().collapseEmptyDivs();
# googletag.pubads().setCentering(true);
# googletag.enableServices();
# // This listener will be called when a slot has finished rendering.
# googletag.pubads().addEventListener('slotRenderEnded', function(event) {
# var slot = event.slot;
# console.group('Slot', slot.getSlotElementId(), 'finished rendering.');
# // Log details of the rendered ad.
# console.log('Advertiser ID:', event.advertiserId);
# console.log('Campaign ID: ', event.campaignId);
# console.log('Creative ID: ', event.creativeId);
# console.log('Is empty?:', event.isEmpty);
# console.log('Line Item ID:', event.lineItemId);
# console.log('Size:', event.size);
# console.groupEnd();
# if (slot.getSlotElementId() === "div-publicidade-fixorodape" && event.isEmpty) {
# console.log("anchor banner is empty")
# }
# });
# });
# //End HEAD code
#   </script>
#   <script type="text/javascript">
#    window._taboola = window._taboola || [];
# _taboola.push({
# home: 'auto'
# });
# ! function(e, f, u, i) {
# if (!document.getElementById(i)) {
# e.async = 1;
# e.src = u;
# e.id = i;
# f.parentNode.insertBefore(e, f);
# }
# }(document.createElement('script'),
# document.getElementsByTagName('script')[0],
# '//cdn.taboola.com/libtrc/epasa-network/loader.js',
# 'tb_loader_script');
# if (window.performance && typeof window.performance.mark == 'function') {
# window.performance.mark('tbl_ic');
# }
#   </script>
#  </head>
#  <body class="html not-front not-logged-in one-sidebar sidebar-first page-secciones page-secciones-economia i18n-es">
#   <div id="skip-link">
#    <a class="element-invisible element-focusable" href="#middle-content">
#     Pasar al contenido principal
#    </a>
#   </div>
#   <div id="div-gpt-ad-1639162438050-0">
#    <script>
#     googletag.cmd.push(function() { googletag.display('div-gpt-ad-1639162438050-0'); });
#    </script>
#   </div>
#   <div class="clearfix" id="footer">
#    <section class="block block-block clearfix" id="block-block-243">
#     <div style="margin: 0 auto; text-align: center; width:970px; padding-bottom:1px;">
#      <script language="JavaScript" type="text/javascript">
#       <!--
# var eplDoc = document, eplLL = false, eS1 = 'us.img.e-planning.net', eplArgs = { iIF:1,sV: schemeLocal() + "://ads.us.e-planning.net/" ,vV:"4",sI:"b7e6",kVs:{  }};
# function eplCheckStart() {
# if (document.epl) {
# var e = document.epl;
# if (e.eplReady()) return true;
# e.eplInit(eplArgs);
# if (eplArgs.custom) {
# for (var s in eplArgs.custom) {
# e.setCustomAdShow(s, eplArgs.custom[s]);
# }
# }
# return e.eplReady();
# } else if (!eplLL) {
# var epl41Script = document.createElement('SCRIPT'); epl41Script.async = true;
# epl41Script.src = schemeLocal() + '://' + eS1 + '/layers/epl-41.js';
# document.head.appendChild(epl41Script);
# eplLL = true;
# }
# return false;
# }
# eplCheckStart();
# function eplSetAd(eID) {
# var opts;
# if (eplCheckStart()) {
# if (eplArgs.sOpts && eplArgs.sOpts[eID]) {
# opts = eplArgs.sOpts[eID];
# if (opts.custF) { document.epl.setCustomAdShow(eID,opts.custF); }
# } else { opts = {}; }
# document.epl.setSpace(eID, opts);
# } else {
# setTimeout(eplSetAd.bind(null, eID), 250);
# }
# }
# function eplAD4(eID, opts) {
# document.write('<div id="eplAdDiv'+eID+'"></div>');
# if (!eplArgs.sOpts) { eplArgs.sOpts = {}; }
# eplArgs.sOpts[eID] = opts || {t:1};
# eplSetAd(eID);
# }
# function schemeLocal() {
# protocol = document.location.protocol || window.top.location.protocol;
# if (protocol) {
# return protocol.indexOf('https') !== -1 ? 'https' : 'http';
# }
# }
# //-->
#      </script>
#      <script>
#       if(panamaamerica.device=="desktop"){
# eplAD4("254d62ab634b07eb",{t:1,timeout:0,ma:1,custF:null,wh:"970x90",sd:"b7e6!!" + schemeLocal() + "://ads.us.e-planning.net/!!", p:"7b38bfe6f062af16"});
# }
#      </script>
#     </div>
#     <div style="margin: 0 auto; text-align: center; width:100%; padding-bottom:1px;">
#      <script language="JavaScript" type="text/javascript">
#       <!--
# var eplDoc = document, eplLL = false, eS1 = 'us.img.e-planning.net', eplArgs = { iIF:1,sV: schemeLocal() + "://ads.us.e-planning.net/" ,vV:"4",sI:"b7e6",kVs:{  }};
# function eplCheckStart() {
# if (document.epl) {
# var e = document.epl;
# if (e.eplReady()) return true;
# e.eplInit(eplArgs);
# if (eplArgs.custom) {
# for (var s in eplArgs.custom) {
# e.setCustomAdShow(s, eplArgs.custom[s]);
# }
# }
# return e.eplReady();
# } else if (!eplLL) {
# var epl41Script = document.createElement('SCRIPT'); epl41Script.async = true;
# epl41Script.src = schemeLocal() + '://' + eS1 + '/layers/epl-41.js';
# document.head.appendChild(epl41Script);
# eplLL = true;
# }
# return false;
# }
# eplCheckStart();
# function eplSetAd(eID) {
# var opts;
# if (eplCheckStart()) {
# if (eplArgs.sOpts && eplArgs.sOpts[eID]) {
# opts = eplArgs.sOpts[eID];
# if (opts.custF) { document.epl.setCustomAdShow(eID,opts.custF); }
# } else { opts = {}; }
# document.epl.setSpace(eID, opts);
# } else {
# setTimeout(eplSetAd.bind(null, eID), 250);
# }
# }
# function eplAD4(eID, opts) {
# document.write('<div id="eplAdDiv'+eID+'"></div>');
# if (!eplArgs.sOpts) { eplArgs.sOpts = {}; }
# eplArgs.sOpts[eID] = opts || {t:1};
# eplSetAd(eID);
# }
# function schemeLocal() {
# protocol = document.location.protocol || window.top.location.protocol;
# if (protocol) {
# return protocol.indexOf('https') !== -1 ? 'https' : 'http';
# }
# }
# //-->
#      </script>
#      <script>
#       if(panamaamerica.device!=="desktop"){
# eplAD4("56819b94a227da0b",{t:1,timeout:0,ma:1,custF:null,wh:"320x50",sd:"b7e6!!" + schemeLocal() + "://ads.us.e-planning.net/!!", });
# }
#      </script>
#     </div>
#     <div class="" id="page">
#      <header class="main-header-2019 header-2021">
#       <div class="main-header-top">
#        <div class="search-2021">
#        </div>
#        <div class="secciones-label-container">
#         <span class="secciones-label hide20-for-small-only">
#          Secciones
#         </span>
#         <div class="main-menu-x">
#          <div class="openmenu2">
#           <div class="bar1">
#           </div>
#           <div class="bar2">
#           </div>
#           <div class="bar3">
#           </div>
#          </div>
#          <div class="bloquear-pag">
#          </div>
#          <div class="links-wrapper">
#           <ul class="links clearboth" id="main-menu-links">
#            <li class="hide20-for-desktop-only">
#             <div class="buscador-header-2019">
#              <form action="//www.panamaamerica.com.pa/buscador" id="search-m" method="get">
#               <input name="cx" type="hidden" value="006265388743205756159:y9ktgnu2wsw"/>
#               <input name="cof" type="hidden" value="FORID:11"/>
#               <input class="buscador-input-txt-2019-m" height="20px" id="qq2" name="string" placeholder="Buscar..." size="70" style="visibility: visible !important; margin:auto; width: 60%;" type="text"/>
#               <label for="btn-cont-search-m">
#                <i aria-hidden="true" class="fa fa-search search-submit-btn-19x" style="padding-right:10px;" type="">
#                </i>
#               </label>
#               <input class="btn-cont-search-m" id="btn-cont-search-m" style="display:none;" type=""/>
#              </form>
#              <li class="menu-nacion has-sub">
#               <a href="/actualidad">
#                Actualidad
#               </a>
#               <ul class="dropdown">
#                <li>
#                 <a href="/politica">
#                  Política
#                 </a>
#                </li>
#                <li>
#                 <a href="/sociedad">
#                  Sociedad
#                 </a>
#                </li>
#                <li>
#                 <a href="/judicial">
#                  Judicial
#                 </a>
#                </li>
#                <li>
#                 <a href="/provincias">
#                  Provincias
#                 </a>
#                </li>
#                <li>
#                 <a href="/mundo">
#                  Mundo
#                 </a>
#                </li>
#                <li>
#                 <a href="/tema/el-trino">
#                  El Trino
#                 </a>
#                </li>
#                <li>
#                 <a href="/aldea-global">
#                  Aldea Global
#                 </a>
#                </li>
#               </ul>
#               <div class="flecha-ddown">
#                <span>
#                </span>
#               </div>
#              </li>
#              <li class="menu-opinion has-sub">
#               <a href="/opinion">
#                Opinión
#               </a>
#               <ul class="dropdown">
#                <li>
#                 <a href="/opinion">
#                  Columnistas
#                 </a>
#                </li>
#                <li>
#                 <a href="/confabulario">
#                  Confabulario
#                 </a>
#                </li>
#                <li>
#                 <a href="/el-pulso">
#                  El Pulso
#                 </a>
#                </li>
#                <li>
#                 <a href="/trazo-del-dia">
#                  Trazo del día
#                 </a>
#                </li>
#                <li>
#                 <a href="/dona-perla">
#                  Doña Perla
#                 </a>
#                </li>
#                <li>
#                 <a href="/tema/ricardo-martinelli">
#                  Ricardo Martinelli
#                 </a>
#                </li>
#               </ul>
#               <div class="flecha-ddown">
#                <span>
#                </span>
#               </div>
#              </li>
#              <li class="menu-economia">
#               <a href="/economia">
#                Economía
#               </a>
#              </li>
#              <li class="menu-variedades">
#               <a href="/variedades">
#                Variedades
#               </a>
#              </li>
#              <li class="menu-deportes">
#               <a href="/deportes">
#                Deportes
#               </a>
#              </li>
#              <li class="menu-tecnologia">
#               <a href="/tecnologia">
#                Tecnología
#               </a>
#              </li>
#              <li class="menu-multimedia has-sub">
#               <a href="/multimedia">
#                Multimedia
#               </a>
#               <ul class="dropdown">
#                <li>
#                 <a href="/videos">
#                  Videos
#                 </a>
#                </li>
#                <li>
#                 <a href="/podcasts">
#                  Podcast
#                 </a>
#                </li>
#                <li>
#                 <a href="/galerias">
#                  Galerías
#                 </a>
#                </li>
#               </ul>
#               <div class="flecha-ddown">
#                <span>
#                </span>
#               </div>
#              </li>
#              <li class="menu-especiales">
#               <a href="/trabajos-especiales">
#                Especiales
#               </a>
#              </li>
#              <li class="menu-impreso">
#               <a href="/impreso">
#                Impreso
#               </a>
#              </li>
#              <li class="menu-premium">
#               <a href="/contenido-premium">
#                Contenido Premium
#               </a>
#              </li>
#              <li class="menu-premiate">
#               <a href="https://premiate.com.pa/" rel="nofollow noopener" target="_blank">
#                <img alt="Prémiate - Club de Beneficios" data-src="/img/logo-premiate-2020.webp" style="width:initial; height:35px"/>
#               </a>
#              </li>
#              <li class="menu-507go">
#               <a aria-label="507 go" href="//507go.tv" rel="nofollow noopener" target="_blank">
#               </a>
#              </li>
#             </div>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="header-2019-logo hide20">
#          <a href="/">
#           <img alt="Panamá América" height="25" src="/img/panamaamerica-logo-183.png" width="183"/>
#          </a>
#         </div>
#         <time class="hide20-for-small-only">
#          Jueves 24 de Marzo de 2022
#         </time>
#         <a class="pa-logo-small hide21-for-small-only" href="/">
#          <img alt="Inicio" src="/img/logo-pa-white.png"/>
#         </a>
#         <div class="page-title-2018" style="display:none">
#          <h2>
#           Economía
#          </h2>
#         </div>
#         <div class="menuregistro-2021">
#          <a aria-label="Membresía" class="cintillo-menbresias-d membresia-cintillo hide21-for-small-only" href="https://suscripcion.panamaamerica.com.pa/" style="background: initial !important;position:initial; margin: auto;">
#           <span style="color:#fff;font-weight:normal !Important;font-size: 13px;">
#            SUSCRÍBETE
#           </span>
#           <span style="color:#fff;font-weight:normal">
#            |
#           </span>
#          </a>
#          <div class="reg-left">
#          </div>
#          <div class="reg-center">
#          </div>
#          <div class="reg-right">
#          </div>
#         </div>
#        </div>
#        <div class="main-header-middle hide21-for-small-only">
#         <div class="header-middle-left">
#          <ul class="siguenos-en-2">
#           <li class="m-instagram">
#            <a href="https://instagram.com/panamaamerica" rel="noopener" target="_blank" title="Instagram">
#             <i class="fa fa-instagram">
#             </i>
#            </a>
#           </li>
#           <li class="icon-first m-facebook">
#            <a href="https://www.facebook.com/PanamaAmerica.com.pa" rel="noopener" target="_blank" title="facebook">
#             <i class="fa fa-facebook">
#             </i>
#            </a>
#           </li>
#           <li class="m-twitter">
#            <a href="https://twitter.com/PanamaAmerica" rel="noopener" target="_blank" title="twitter">
#             <i class="fa fa-twitter">
#             </i>
#            </a>
#           </li>
#           <li class="m-youtube">
#            <a href="https://www.youtube.com/user/diariopanamaamerica" rel="noopener" target="_blank" title="Youtube">
#             <i aria-hidden="true" class="fa fa-youtube-play">
#             </i>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="header-middle-center">
#          <a href="/" title="Ir a la portada">
#           <img alt="Panamá América" height="46" src="/img/panamaamerica-logo-345.png" width="345"/>
#          </a>
#         </div>
#         <div class="header-middle-right">
#          <div class="buscador-header-2019">
#           <form action="//www.panamaamerica.com.pa/buscador" id="search" method="get">
#            <input name="cx" type="hidden" value="006265388743205756159:y9ktgnu2wsw"/>
#            <input name="cof" type="hidden" value="FORID:11"/>
#            <input class="buscador-input-txt-2019" height="20px" id="qq" name="string" placeholder="Buscar..." size="70" type="text"/>
#            <label for="btn-cont-search">
#             <i aria-hidden="true" class="fa fa-search search-submit-btn-19x" type="">
#             </i>
#            </label>
#            <input class="btn-cont-search" id="btn-cont-search" style="display:none;" type=""/>
#           </form>
#          </div>
#         </div>
#        </div>
#        <div class="progressContainer" style="display:none">
#         <div class="progress" id="progress" style="">
#         </div>
#        </div>
#        <nav class="main-header-menu hide-on-small-only hide20-for-small-only">
#         <div class="main-header-menu-inside" style="display:flex; margin:auto">
#          <ul class="main-menu-links-2019">
#           <script>
#            const search = document.querySelector('#search');
# const search2021Container = document.querySelector('.header-2021 .search-2021');
# if(search2021Container !== null && search !== null){
# search.parentElement.remove();
# search2021Container.innerHTML = '<div class="buscador-header-2019">' + search.outerHTML +'</div>';
# }
#           </script>
#           <li>
#            <a href="/actualidad">
#             Actualidad
#            </a>
#           </li>
#           <li>
#            <a href="/opinion">
#             Opinión
#            </a>
#           </li>
#           <li>
#            <a href="/economia">
#             Economìa
#            </a>
#           </li>
#           <li>
#            <a href="/variedades">
#             Variedades
#            </a>
#           </li>
#           <li>
#            <a href="/deportes">
#             Deportes
#            </a>
#           </li>
#           <li>
#            <a href="/tecnologia">
#             Tecnología
#            </a>
#           </li>
#           <li>
#            <a href="/multimedia">
#             Multimedia
#            </a>
#           </li>
#           <li>
#            <a href="/impreso">
#             Impreso
#            </a>
#           </li>
#           <li class="c-premium-19" style="width:150px !important;">
#            <a href="/contenido-premium">
#             <img alt="Contenido premium" height="35" src="/img/contenido-premium-logo.webp" width="146"/>
#            </a>
#           </li>
#           <li class="hide21-for-small-only" style="padding:0 14px">
#            <a aria-label="Prémiate" href="https://premiate.com.pa/" rel="nofollow noopener" target="_blank">
#             <img alt="" height="36" src="/img/logo-premiate-2020-blue-196.webp" style="max-width:235px !important;min-height: 35px;" width="240"/>
#            </a>
#           </li>
#          </ul>
#          <ul class="siguenos-en-2">
#           <li class="m-instagram">
#            <a href="https://instagram.com/panamaamerica" rel="noopener" target="_blank" title="Instagram">
#             <i class="fa fa-instagram">
#             </i>
#            </a>
#           </li>
#           <li class="icon-first m-facebook">
#            <a href="https://www.facebook.com/PanamaAmerica.com.pa" rel="noopener" target="_blank" title="facebook">
#             <i class="fa fa-facebook">
#             </i>
#            </a>
#           </li>
#           <li class="m-twitter">
#            <a href="https://twitter.com/PanamaAmerica" rel="noopener" target="_blank" title="twitter">
#             <i class="fa fa-twitter">
#             </i>
#            </a>
#           </li>
#           <li class="m-youtube">
#            <a href="https://www.youtube.com/user/diariopanamaamerica" rel="noopener" target="_blank" title="Youtube">
#             <i aria-hidden="true" class="fa fa-youtube-play">
#             </i>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </nav>
#        <div class="membresia-cintillo-m hide20">
#         <span>
#          <span>
#           jueves
#          </span>
#          24 de marzo de 2022
#         </span>
#         <div>
#          <img alt="Suscripción" height="23" src="/img/login/icono-membresia-70.webp?v2" width="23"/>
#          <span>
#           <a class="" href="https://suscripcion.panamaamerica.com.pa/">
#            SUSCRÍBETE
#           </a>
#          </span>
#         </div>
#        </div>
#        <nav class="menu-usuario" style="display:none">
#         <ul>
#          <li class="close-menu" onclick="toogleUserMenu()">
#           x
#          </li>
#          <li class="mi-cuenta">
#           <span>
#            Mi cuenta
#           </span>
#          </li>
#          <li>
#           <a href="//www.panamaamerica.com.pa/mi-perfil">
#            <img alt="" data-src="/img/login/iconos/miperfil.png" height="21" width="21"/>
#            <span>
#             Mi perfil
#            </span>
#           </a>
#          </li>
#          <li class="mi-membresia-li">
#          </li>
#          <li>
#           <a href="/premiate">
#            <img alt="Prémiate" height="31" src="/img/logo-premiate-2020-blue-196.webp" style="width: 48%;height: 31px !important; max-height: 31px !important;" width="90"/>
#           </a>
#          </li>
#          <li>
#           <a href="//www.panamaamerica.com.pa/mis-boletines">
#            <img alt="" data-src="/img/login/iconos/boletines.png" height="21" width="21"/>
#            <span>
#             Mis boletines
#            </span>
#           </a>
#          </li>
#          <li>
#           <a href="//www.panamaamerica.com.pa/seguridad">
#            <img alt="" data-src="/img/login/iconos/seguridad.png" height="21" width="21"/>
#            <span>
#             Seguridad
#            </span>
#           </a>
#          </li>
#          <li class="cerrar-sesion-li last">
#          </li>
#         </ul>
#        </nav>
#        <div class="row page grid news-articles-section-wrapper">
#         <section class="main container" role="main">
#          <section class="block block-block clearfix" id="block-block-559">
#           <meta content="180" http-equiv="refresh"/>
#          </section>
#          <div class="content-sidebar-1 content-news-wrapper">
#           <div class="col l9 m12 s12 content-1 content-news-inside">
#            <section class="block block-system clearfix" id="block-system-main">
#             <div class="view view-home-2018- view-id-home_2018_ view-display-id-page_1 view-dom-id-c62f24c9b6e171096487e2ddf3fcce18">
#              <div class="view-header">
#               <style>
#                .page-title-2018{
# }
# .content-sidebar-2{display:none !important}
# .subtitle-mn{
# display:block;clear:both;
# font-size:15px!important;color:#0e65a5 !important; text-transform:initial !important;font-weight:bold
# }
#               </style>
#               <h1 class="hide20-for-desktop-only">
#                Economía
#               </h1>
#              </div>
#              <div class="view-content l9 m9 col">
#               <article class="panel-seccion-2018 panel news-article first last odd">
#                <span class="subtitulo">
#                 Panamá
#                </span>
#                <h2 class="titulo col l12 m12">
#                 <a href="/economia/panamenos-quieren-sabonge-fuera-del-mop-1204175">
#                  Panameños quieren a Sabonge fuera del MOP
#                 </a>
#                </h2>
#                <figure class="imagen col l12 m12">
#                 <a href="/economia/panamenos-quieren-sabonge-fuera-del-mop-1204175">
#                  <img alt="Rafael Sabonge es uno de los ministros más cuestionados por su gestión como titular del MOP. Foto: Grupo Epasa" height="354" src="https://www.panamaamerica.com.pa/sites/default/files/styles/home_2018_712x354/public/imagenes/2022/03/24/rafael-sabonge.jpg?itok=GfRGfGWv" title="Rafael Sabonge es uno de los ministros más cuestionados por su gestión como titular del MOP. Foto: Grupo Epasa" width="712"/>
#                 </a>
#                </figure>
#                <p class="resumen col l12 m12">
#                 El ministro Rafael Sabonge es el primero en la lista de cambios en el Gabinete, según reveló la última encuesta de Gallup Panamá.
#                </p>
#               </article>
#              </div>
#              <div class="view-footer">
#               <div class="view view-home-2018- view-id-home_2018_ view-display-id-block_12 l3 m3 col view-dom-id-a77d3e10a50d4bb0a0fd507cf18590f8">
#                <div class="view-content">
#                 <article class="panel-2018-seccion-derecha panel news-article first odd">
#                  <figure class="imagen">
#                   <a href="/economia/sin-tregua-nuevo-incremento-en-el-costo-de-la-gasolina-y-el-diesel-partir-del-viernes">
#                    <img alt="Nueva alza en el precio del combustible enfrentan panameños. Foto: Archivos" height="198" src="https://www.panamaamerica.com.pa/sites/default/files/styles/home_2018_302x192/public/imagenes/2022/03/23/gasolina-precio-panama.jpg?itok=sGU-hy87" title="Nueva alza en el precio del combustible enfrentan panameños. Foto: Archivos" width="302"/>
#                   </a>
#                  </figure>
#                  <span class="subtitulo">
#                   Panamá
#                  </span>
#                  <h2 class="titulo">
#                   <a href="/economia/sin-tregua-nuevo-incremento-en-el-costo-de-la-gasolina-y-el-diesel-partir-del-viernes">
#                    ¡Sin tregua! Nuevo incremento en el costo de la gasolina y el diésel a partir del viernes
#                   </a>
#                  </h2>
#                  <span class="seccion-autor">
#                  </span>
#                 </article>
#                 <article class="panel-2018-seccion-derecha panel news-article last even">
#                  <figure class="imagen">
#                   <a href="/economia/laurentino-cortizo-hablo-de-una-economia-solida-y-pujante-los-empresarios-en-expocomer-2022">
#                    <img alt="Expocomer, la feria multisectorial más importante de América Latina, se inauguró este 23 de marzo. Foto: Cortesía" height="198" src="https://www.panamaamerica.com.pa/sites/default/files/styles/home_2018_302x192/public/imagenes/2022/03/23/expocomer-2022_0.jpg?itok=smJriEBy" title="Expocomer, la feria multisectorial más importante de América Latina, se inauguró este 23 de marzo. Foto: Cortesía" width="302"/>
#                   </a>
#                  </figure>
#                  <span class="subtitulo">
#                   Panamá
#                  </span>
#                  <h2 class="titulo">
#                   <a href="/economia/laurentino-cortizo-hablo-de-una-economia-solida-y-pujante-los-empresarios-en-expocomer-2022">
#                    Laurentino Cortizo habló de una economía 'sólida y pujante' a los empresarios en Expocomer 2022
#                   </a>
#                  </h2>
#                  <span class="seccion-autor">
#                  </span>
#                 </article>
#                </div>
#               </div>
#               <div class="view view-home-2018- view-id-home_2018_ view-display-id-block_10 view-dom-id-a931324d4d845e6b9b1492d41e01c7ef">
#                <div class="view-header">
#                 <div id="div-gpt-ad-1636994012933-0" style="padding-bottom: 15px">
#                  <script>
#                   googletag.cmd.push(function() { googletag.display('div-gpt-ad-1636994012933-0'); });
#                  </script>
#                 </div>
#                </div>
#                <div class="view-content">
#                 <article class="panel-2018-seccion-abajo panel news-article first odd">
#                  <div>
#                   <div class="">
#                    <figure class="imagen col l3 m3 s12">
#                     <a href="/economia/spia-una-huelga-en-la-construccion-afectara-todos-los-panamenos-1204069">
#                      <img alt="La construcción es un sector importante para la economía del país que se ha visto afectada en los últimos dos años. Foto: Grupo Epasa" data-src="https://www.panamaamerica.com.pa/sites/default/files/styles/home_2018_302x192/public/imagenes/2022/03/23/construccion-huelga.jpg?itok=xf9yvP-J" height="400" width="630"/>
#                     </a>
#                    </figure>
#                    <div class="col l9 m9 s12">
#                     <span class="subtitulo">
#                      Panamá
#                     </span>
#                     <h2 class="titulo">
#                      <a href="/economia/spia-una-huelga-en-la-construccion-afectara-todos-los-panamenos-1204069">
#                       SPIA: una huelga en la construcción afectará a todos los panameños
#                      </a>
#                     </h2>
#                     <span class="seccion-autor">
#                      Redacción/
#                      <a class="__cf_email__" data-cfemail="6907080a000607471908290c19081a08470a0604" href="/cdn-cgi/l/email-protection">
#                       [email protected]
#                      </a>
#                      /@panamaamerica
#                     </span>
#                     <p class="resumen">
#                      La SPIA considera que es necesario que prevalezca el diálogo con el fin de lorar un consenso que beneficie a ambas partes.
#                     </p>
#                    </div>
#                   </div>
#                  </div>
#                 </article>
#                 <article class="panel-2018-seccion-abajo panel news-article even">
#                  <div>
#                   <div class="">
#                    <figure class="imagen col l3 m3 s12">
#                     <a href="/economia/duenos-de-restaurantes-aseguran-que-estan-esforzandose-para-no-subir-precios-consumidores">
#                      <img alt="Los precios en los restaurantes podrían subir en los próximos días. Foto: Grupo Epasa" data-src="https://www.panamaamerica.com.pa/sites/default/files/styles/home_2018_302x192/public/imagenes/2022/03/23/restaurantes-precios.jpg?itok=WaNyqWSN" height="400" width="630"/>
#                     </a>
#                    </figure>
#                    <div class="col l9 m9 s12">
#                     <span class="subtitulo">
#                      Panamá
# ...
#             </script>
#            </div>
#           </div>
#          </section>
#          <section class="block block-block clearfix" id="block-block-589">
#           <footer>
#            <div class="new-pie">
#             <div class="gray-line">
#             </div>
#             <div class="container">
#              <div class="row">
#               <div class="col l3 m3 s12">
#                <img alt="Panamá América" data-src="/img/logo-pa.png" height="27" width="193"/>
#                <ul class="inline-list share">
#                 <li>
#                  <span>
#                   Siguenos en:
#                  </span>
#                 </li>
#                 <li>
#                  <a href="https://instagram.com/panamaamerica" rel="noopener noreferrer" target="_blank" title="Instagram">
#                   <i aria-hidden="true" class="fa fa-instagram">
#                   </i>
#                  </a>
#                 </li>
#                 <li>
#                  <a href="https://www.facebook.com/PanamaAmerica.com.pa" rel="noopener noreferrer" target="_blank" title="facebook">
#                   <i class="fa fa-facebook">
#                   </i>
#                  </a>
#                 </li>
#                 <li>
#                  <a href="https://twitter.com/PanamaAmerica" rel="noopener noreferrer" target="_blank" title="twitter">
#                   <i class="fa fa-twitter">
#                   </i>
#                  </a>
#                 </li>
#                 <li>
#                  <a href="https://www.youtube.com/user/diariopanamaamerica" rel="noopener noreferrer" target="_blank" title="Youtube">
#                   <i aria-hidden="true" class="fa fa-youtube-play">
#                   </i>
#                  </a>
#                 </li>
#                </ul>
#                <div class="lab-content">
#                 <span class="dash">
#                  <a href="/contenido-premium" title="Contenido Premium">
#                   <img alt="Contenido premium" data-src="/imagenes/cont_premium.webp" height="42" width="159"/>
#                  </a>
#                 </span>
#                </div>
#               </div>
#               <div class="col l3 m3 l-left">
#                <div>
#                 <a href="https://registro.panamaamerica.com.pa/login/inscribete.php" rel="noopener" target="_blank">
#                  Regístrate
#                 </a>
#                </div>
#                <div>
#                 <a href="/registro/login">
#                  Inicia sesión
#                 </a>
#                </div>
#                <div>
#                 <a href="/impreso">
#                  Impreso
#                 </a>
#                </div>
#               </div>
#               <div class="col l4 m4 s12">
#                <div class="row">
#                 <div class="col l6 m6 s6">
#                  <div>
#                   <a href="//www.panamaamerica.com.pa">
#                    Panamá América
#                   </a>
#                  </div>
#                  <div>
#                   <a href="//www.critica.com.pa" rel="noopener" target="_blank">
#                    Crítica
#                   </a>
#                  </div>
#                  <div>
#                   <a href="//www.diaadia.com.pa" rel="noopener" target="_blank">
#                    Día a Día
#                   </a>
#                  </div>
#                  <div>
#                   <a href="//www.mujer.com.pa" rel="noopener" target="_blank">
#                    Mujer
#                   </a>
#                  </div>
#                  <div>
#                   <a href="http://recetas.com.pa" rel="noopener" target="_blank">
#                    Recetas
#                   </a>
#                  </div>
#                 </div>
#                 <div class="col l6 m6 s6">
#                  <div>
#                   <a href="//impresos.epasa.com.pa" rel="noopener" target="_blank">
#                    Impresos
#                   </a>
#                  </div>
#                  <div>
#                   <a href="//www.cine.com.pa" rel="noopener" target="_blank">
#                    Cine
#                   </a>
#                  </div>
#                  <div>
#                   <a href="//www.clasiguia.com.pa" rel="noopener" target="_blank">
#                    Clasiguía
#                   </a>
#                  </div>
#                  <div>
#                   <a href="//premiate.com.pa" rel="noopener" target="_blank">
#                    Prémiate
#                   </a>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <ul class="col l4 m4 s12 footer-menu" style="display:flex; flex-wrap:wrap; margin:7px auto 20px auto">
#                <li>
#                 <div>
#                  <a href="https://www.panamaamerica.com.pa/actualidad">
#                   Noticias
#                  </a>
#                 </div>
#                </li>
#                <li>
#                 <div>
#                  <a href="https://www.panamaamerica.com.pa/videos">
#                   Videos
#                  </a>
#                 </div>
#                </li>
#                <li>
#                 <div>
#                  <a href="https://www.panamaamerica.com.pa/tema/exclusivo-web">
#                   Exclusivo Web
#                  </a>
#                 </div>
#                </li>
#                <li>
#                 <div>
#                  <a href="https://www.panamaamerica.com.pa/opinion">
#                   Columnas
#                  </a>
#                 </div>
#                </li>
#               </ul>
#               <div class="col l2 m2" style="padding-left: 15px;">
#                <div class="row">
#                 <div class="large-12 medium-12 columns" style="padding-left: 50px;">
#                  <p class="diario-asociados">
#                   Miembro de:
#                  </p>
#                  <img alt="Miembro del PAL" data-src="/img/logo-PAL.webp?dmmdmd" height="50" width="98"/>
#                  <div style="margin-top: 15px;">
#                  </div>
#                  <img alt="Sociedad de prensa" data-src="/img/logo-sociedad-prensa.webp" height="47" width="135"/>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="red-line">
#             </div>
#             <div class="container">
#              <div class="row texto" style="text-align:center">
#               <div class="col l12">
#                <p class="center-align">
#                 Todos los derechos reservados Editora Panamá América S.A. - Ciudad de Panamá - Panamá 2022.
#                </p>
#                <p class="center-align">
#                 Prohibida su reproducción total o parcial, sin autorización escrita de su titular.
#                </p>
#               </div>
#              </div>
#             </div>
#            </div>
#           </footer>
#           <div class="cookies">
#            <div class="chip">
#             <span>
#              Utilizamos cookies propias y de terceros para mejorar nuestros servicios y mostrarle publicidad relacionada con sus preferencias mediante el análisis de sus hábitos de navegación. Si continua navegando, consideramos que acepta su uso. Puede cambiar la configuración u obtener más información
#              <a href="/politicas-de-cookies">
#               "aquí"
#              </a>
#              .
#             </span>
#             <i class="fa fa-close close material-icons">
#             </i>
#            </div>
#           </div>
#          </section>
#          <section class="block block-block clearfix" id="block-block-438">
#           <div class="contenidomodal-2018">
#           </div>
#           <div class="cajavacia-2018">
#           </div>
#           <script>
#            var cajavacia = document.querySelector('.cajavacia-2018'); window.addEventListener("message", respuesta, false);var res;function respuesta (event) {if(event.data=="crearcuenta"){desbloquearPantalla();mostrarCrearCuenta();}if(event.data=="iniciarsesion"){desbloquearPantalla();mostrarIniciarSesion();}if(event.data=="cerrarmodal"){desbloquearPantalla();}if(event.data=="quitarperfil"){window.location.href="/";return;}if(event.data=="crear450"){jQuery(".mostrar-modal.modal-crear").addClass("crear450");}if(event.data=="returnToHome"){window.location.href = "/";}if(event.data=="cfUpdated"){if(typeof(paywall) !==undefined){paywall.signOff();}document.cookie = "gtx8id=null;expires=Thu, 01 Jan 1970 00:00:00 GMT;path=/";window.location.href = "/";}} jQuery(".cajavacia-2018").click(function() {    ocultarCrearCuenta();});function revisarPremium(){if(jQuery("article.nota-premium").length >0){bloquearArticulo();}}function bloquearArticulo(){if (typeof(jQuery(".nota-restriccion-msg").html()) === "undefined"){jQuery(".notas-body .robapagina-centreado").remove();jQuery("#comments18-wrapper").remove();jQuery("#share-comments").remove();jQuery(".view-las-mas-leidas-nueva").remove();jQuery("#taboola-below-homepage-thumbnails").remove();jQuery("#block-block-534").remove();jQuery("#block-block-683").remove();jQuery(".reacciones").remove();jQuery("#pocoton-products").remove();if(jQuery(".notas-body .notas > div >*:nth-child(1)").text().trim().length < 80){jQuery(".notas-body .notas > div >*:nth-child(n+3)").remove();}else jQuery(".notas-body .notas > div >*:nth-child(n+2)").remove(); jQuery(".notas-body .notas > div >*:nth-child(1)").css({"height": "140px", "overflow": "hidden"});jQuery(".notas-body .notas > div >*").wrapAll('<div class="preview-premium"></div>');jQuery(".preview-premium").append('<div class="preview-premium-sombra"></div>');jQuery(".notas-body").append('<div class="nota-restriccion-msg"><div class="restriccion-header"><div></div><span><img class="bloqueo-star-w" src="/img/star-blanca35.png"></span><div></div></div><div class="restriccion-title">Inicia sesión para seguir leyendo</div><div class="restriccion-desc">Solo con tener una cuenta ya puedes leer este artículo, es GRATIS.</div><div class="restriccion-btns-registro"><span class="registrate-aqui-btn-new">Regístrate</span><span class="inicia-ses-btn-new">Ingresar</span></div><div class="restriccion-footer">Gracias por leer <b>Panamá América</b></div></div>');jQuery(".registrate-aqui-btn-new").on("click",function() {mostrarCrearCuenta();});jQuery(".inicia-ses-btn-new").on("click",function() {mostrarIniciarSesion();});}}function mostrarLoader(){return;}function mostrarCrearCuenta(){let isPremium;if(document.getElementsByClassName("nota-premium")[0] !== undefined){isPremium = true;}else{isPremium = false;}window.location.href= '/registro/crear?next='+ btoa(document.URL) +'&pr='+isPremium;return;desbloquearPantalla();bloquearPantalla();mostrarLoader();jQuery('.contenidomodal-2018').addClass('mostrar');jQuery('.contenidomodal-2018').addClass('mostrar-modal');jQuery('.contenidomodal-2018').addClass('modal-crear');let w = screen.width;jQuery('.contenidomodal-2018').append('<if'+'rame src="//registro.panamaamerica.com.pa/login/logintest.php?crear&w='+w+'&nodeid&sname=panamaamericacompa&nodeid=secciones/economia&ruta=//www.panamaamerica.com.pa&path=/economia&pr='+isPremium+'&"></if'+'rame>');}function mostrarIniciarSesion(){let isPremium;if(document.getElementsByClassName("nota-premium")[0] !== undefined){isPremium = true;}else{isPremium = false;}window.location.href= '/registro/login?next='+ btoa(document.URL.split('?')[0]) +'&pr='+isPremium;return;let w = screen.width;bloquearPantalla();mostrarLoader();jQuery('.contenidomodal-2018').addClass('mostrar');jQuery('.contenidomodal-2018').addClass('mostrar-modal');jQuery('.contenidomodal-2018').addClass('modal-login');jQuery('.contenidomodal-2018').append('<if'+'rame src="//registro.panamaamerica.com.pa/login/logintest.php?login&w ...
#           </script>
#          </section>
#          <section class="block block-block clearfix" id="block-block-785">
#           <div id="div-publicidade-fixorodape" style="width: 100%; bottom: 0; z-index: 999; position: fixed; left:0; right:0;">
#            <script>
#             <!--//--><![CDATA[// ><!--
# googletag.cmd.push(function () {
# googletag.display("div-publicidade-fixorodape");
# });
# //--><!]]>
#            </script>
#           </div>
#          </section>
#         </div>
#         <div class="footer-copyright">
#         </div>
#        </footer>
#       </div>
#       <script async="async" src="/sites/all/themes/panamaamerica_materialize/js/custom-ser.js?55s5sccc3">
#       </script>
#       <link as="style" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css?display=swap" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#       <noscript>
#        <link href="https://fonts.googleapis.com/css?family=Montserrat&amp;display=swap" rel="stylesheet" type="text/css"/>
#       </noscript>
#       <link as="style" href="/sites/all/themes/mobilepa2016/css/registro.css?v5" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#       <noscript>
#        <link href="/sites/all/themes/mobilepa2016/css/registro.css?v4" media="all" rel="stylesheet" type="text/css"/>
#       </noscript>
#       <script>
#        !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window,document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '1993521960918834');
# fbq('track', 'PageView');
#       </script>
#       <noscript>
#        <img alt="" height="1" src="https://www.facebook.com/tr?id=1993521960918834&amp;ev=PageView&amp;noscript=1" style="height:1px !important; width:1px !important;" width="1"/>
#       </noscript>
#       <ins data-revive-id="11dac5182c2ea03a67dd87cdf9937cd5" data-revive-zoneid="108">
#       </ins>
#       <script async="" src="//adserver.latinon.com/revive/www/delivery/asyncjs.php">
#       </script>
#       <div id="ads_9BWEJN40YOG8">
#       </div>
#       <script language="javascript" type="text/javascript">
#        (function(){
# var newscript= document.createElement('script');
# newscript.type = 'text/javascript';
# newscript.async = true;
# lz_elem = (document.getElementsByTagName('head')[0]||document.getElementsByTagName('body')[0]);
# lz_elem.appendChild(newscript);
# newscript.onload = function(ev){
# var lz_url="https://play.sunmediaads.com/red/zone.php?code=9BWEJN40YOG8&a=&pubid=&lgid="+((new Date()).getTime() % 2147483648) + Math.random();
# var lz_target = "ads_9BWEJN40YOG8";
# var lz_sync_mode=false;
# lz_loadads(lz_url ,lz_target,lz_sync_mode);
# }
# newscript.src= "https://img.sunmediaads.com/ads/lz_loader.js?ver=1.4";
# })();
#       </script>
#       <script>
#        function a(r){try{for(;r.parent&&r!==r.parent;)r=r.parent;return r}catch(r){return null}}var n=a(window);if(n&&n.document&&n.document.body){var s=document.createElement("script");s.src="https://static.sunmedia.tv/integrations/36a67915-2d1d-4e81-9e13-f35c23133487/36a67915-2d1d-4e81-9e13-f35c23133487.js",s.async=!0,n.document.body.appendChild(s)}
#       </script>
#       <script>
#        if(panamaamerica.device =="desktop"){
# var vidoomy= document.createElement('script');
# vidoomy.src = 'https://ads.vidoomy.com/panamaamericacompa_1028.js';
# vidoomy.rel = 'text/javascript';
# vidoomy.async = 'async';
# document.getElementsByTagName('head')[0].appendChild(vidoomy);
# }
#       </script>
#       <style>
#        .scrolly .premiatecintillo{
# display:none !important;
# }
# .bloquear-pag{
# overflow:hidden;
# }
# .main.container > .google-auto-placed, #page> .google-auto-placed{
# transform: scale(.88);
# margin-top: -10px;
# padding-bottom:15px;
# }
#       </style>
#       <script crossorigin="anonymous" data-cf-beacon='{"rayId":"6f0fd335bd046db5","token":"9fce0dca25484fd7841c5d204350a792","version":"2021.12.0","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194">
#       </script>
#      </header>
#     </div>
#    </section>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ### Enlaces a los artículos de economía

# %%
articles = economia_soup.find('div', attrs={'class':'view-footer'}).find_all('article')
economia_articles_url = [article.a.get('href') for article in articles]
economia_articles_url
# Out:
# ['/economia/sin-tregua-nuevo-incremento-en-el-costo-de-la-gasolina-y-el-diesel-partir-del-viernes',
#  '/economia/laurentino-cortizo-hablo-de-una-economia-solida-y-pujante-los-empresarios-en-expocomer-2022',
#  '/economia/spia-una-huelga-en-la-construccion-afectara-todos-los-panamenos-1204069',
#  '/economia/duenos-de-restaurantes-aseguran-que-estan-esforzandose-para-no-subir-precios-consumidores',
#  '/economia/medidas-largo-plazo-para-enfrentar-aumento-de-los-combustibles-1204060',
#  '/economia/sabonge-contrato-empresas-senaladas-en-escandalos-1204059',
#  '/economia/otra-vez-aumentara-la-gasolina-pero-se-tratara-de-estabilizar-el-precio-del-diesel-1204040',
#  '/economia/aplafa-pandemia-deja-una-crisis-de-salud-mental-en-ninos-ninas-y-adolescentes-1204043',
#  '/economia/transformando-los-sistemas-agroalimentarios-de-la-vision-global-la-accion-regional-1204003',
#  '/economia/los-desafios-para-innovar-en-salud-en-panama-1204001',
#  '/economia/trabajadores-de-tierra-de-copa-ante-una-inminente-huelga-desde-el-viernes-1204002',
#  '/economia/petroleo-de-texas-sube-hasta-un-71-y-se-situa-en-11212-dolares-el-barril-1203982',
#  '/economia/crudo-de-texas-abre-al-alza-y-pone-en-jaque-gobiernos-de-paises-importadores-1203977',
#  '/economia/capac-llama-trabajadores-de-la-construccion-no-apoyar-huelga-convocada-por-el-suntracs',
#  '/economia/panama-con-un-buro-de-credito-eficiente-pero-urgido-de-tecnologias-1203951',
#  '/economia/reactivacion-economica-en-panama-afectada-por-conflicto-belico-1203950',
#  '/economia/secretario-de-energia-no-vemos-una-reduccion-en-el-precios-del-combustible-para-los',
#  '/economia/agricultura-chiricana-se-dirige-un-nuevo-modelo-1203921',
#  '/economia/fletes-de-legumbres-y-vegetales-aumenta-1203871',
#  '/economia/bimbo-y-trabajadores-alcanzan-acuerdo-laboral-la-huelga-llega-su-fin-1203818']

# %% [markdown]
# ### Títulos de los artículos

# %%
article_url = HOME_URL + economia_articles_url[7]

article_response = requests.get(article_url)
article_soup = BeautifulSoup(article_response.content, 'lxml')
#print(article_soup.prettify())

# %%
article_soup.find('h1').get_text()
# Out:
# 'Aplafa: Pandemia deja una crisis de salud mental en niños, niñas y adolescentes'

# %% [markdown]
# ### Vecha de publicación

# %%
date = article_soup.find('li', attrs={'class':'fecha-hora'}).get_text()
date = re.findall(r'[0-9]*/[0-9]*/[0-9]{2,4}', date)
date
# Out:
# ['22/3/2022']

# %% [markdown]
# ### Resumen del artículo

# %%
article_soup.find('p', attrs={'class':'subheader'}).get_text()
# Out:
# 'Advierten impacto que el cierre de los centros educativos y el encierro de niños, niñas y adolescentes en hogares, muchas veces bajo situaciones de violencia o pobreza, han tenido en la salud mental de los menores.'

# %% [markdown]
# ### Cuerpo del artículo

# %%
par = article_soup.find_all('p')[3:-6]
[pr.get_text() for pr in par]
# Out:
# ['Trastornos depresivos, conducta bipolar, intento de suicidio, problemas relacionados al duelo y retraso mental, principales atenciones en paidosiquiatría de la Caja de Seguro Social. Foto: Pixabay',
#  'Un 32% de los niños, niñas y adolescentes en Panamá sintieron molestias en su salud mental a raíz de la pandemia por covid-19 y en 8 de cada 10 hogares existía preocupación por el impacto de la pandemia en la salud mental de los niños y niñas, reveló informe de la Unicef en noviembre 2021.',
#  'Durante los últimos dos años, la salud mental es un tema recurrente en las atenciones de niños, niñas y adolescentes, afirma la gerente de Planificación y Evaluación de la Asociación Panameña para el Planeamiento de la Familia (Aplafa), Yuri Pittí.',
#  'Pittí advierte el impacto que el cierre de los centros educativos y el encierro de niños, niñas y adolescentes en hogares, muchas veces bajo situaciones de violencia o pobreza, han tenido en la salud mental de los menores.',
#  'Las mayores recurrencia durante la pandemia son las atenciones de menores que enfrentaban dificultades para seguir los planes de educación virtual, aquellos que quedaron al cuidado de otras personas con la reactivación económica, y en general, situaciones por menores afectados por situaciones económicas, detalla la experta.',
#  'Jóvenes que no han podido continuar pagando sus universidades, y que enfrentan dificultades para acceder a los empleos, también están entre las situaciones identificadas en la Aplafa.',
#  'Esta realidad se reflejará tras el retorno a las aulas, con estudiantes con grandes deficiencias académicas, que provienen de familias que han perdido familiares a causa de la covid-19, o han enfrentado círculos de violencias.\n\n',
#  '"Esta crisis de salud mental afectará el futuro como estas personas se van a relacionar con sus familias, parejas y las formas cómo llevarán sus proyectos de vida", advierte Pittí.',
#  'El aislamiento, los cambios repentinos de conductas, autolesiones, comentarios de posible intención de atentar contra su vida, son señales que no pueden pasar desapercibidas.',
#  'VEA TAMBIÉN: Unesco: A estudiantes de Panamá les cuesta desarrollar ideas en escritura',
#  'Que un menor advierta que está incómodo con una persona adulta, tampoco se puede dejar pasar por alto, agrega Pittí. Los adultos deben dejar de pensar que los problemas solo los tienen los adultos, y empezar a identificar, escuchar y atender las necesidades que tiene los niños, niñas y adolescentes, señala Pittí.',
#  'Pittí también advierte una población que está recibiendo poca información sobre la violencia digital. El control, las amenazas y el seguimiento a través de los dispositivos móviles es una constaste y una banderas rojas entre las parejas de jóvenes y adolescentes que dan paso a situacionesviolencia doméstica.',
#  'La Aplafa cuenta con el programa de Juventud con Opciones en San Miguelito y Santiago para atender a jóvenes de 12 a 25 años de edad, donde se les brinda educación integral en sexualidad, con herramientas para mejorar la calidad de vida, las relaciones familiares, sociales, y se trabaja en proyecto de vida y planificación familiar. Igualmente, cuenta con programas de consejería a las familias y para hombres.',
#  'Pittí concluye que en Panamá hace falta políticas de Estados para atender esta realidad que se agravó con la pandemia de la covid-19.',
#  'Durante el primer semestre del 2021, en atención de paidosiquiatría de la Caja de Seguro Social se hospitalizaron 36 pacientes, siendo el grupo de 16 años, el más afectado con predominio de trastornos depresivos, conducta bipolar, intento de suicidio, problemas relacionados al duelo y retraso mental.',
#  'En consulta externa se reportaron 3,855 pacientes con diagnóstico de trastornos de aprendizaje a raíz de las clases virtuales, además de estrés postraumático, autismo, depresión y de déficit de atención con hiperactividad.',
#  'La encuesta de Unicef también reveló afectaciones en la salud mental de los cuidadores en Panamá, donde cerca del 58% de los encuestados reportó alguna desmejora en su salud mental a raíz de la pandemia; un aumento de 10 puntos en comparación con noviembre de 2020.']

# %% [markdown]
# ## Scraper

# %%
def getHomePage(HOME_URL):
    """Recibe el enlace de la página y hace la consulta"""
    
    try:
        response = requests.get(HOME_URL) # Consulta a la página a scrapear
        if response.status_code == 200:
            home_soup = BeautifulSoup(response.content, 'lxml')
            return home_soup
        
    except Exception as e:
        print(e)

# %%
def getNavSections(home_soup):
    """Recibe la sopa de la página principal, retorna los enlaces de las secciones"""
    
    try:
        nav_soup = home_soup.find('ul', attrs={'class':'main-menu-links-2019'}).find_all('li')[:-3]
        navs = [sec.a.get('href') for sec in nav_soup]
        return navs[2] 
    
    except Exception as e:
        print(e)

# %%
def getSectionNewsLinks(HOME_URL, economia_section):
    """Recibe los enlaces de las secciones, retorna los enlaces de las noticias en ellas """
    
    economia_blog = HOME_URL + economia_section
    section_response = requests.get(economia_blog) # Consulta las secciones
    economia_news_url = []    
    try:
        if section_response.status_code == 200:
            articles = economia_soup.find('div', attrs={'class':'view-footer'}).find_all('article')
            economia_articles_url = [article.a.get('href') for article in articles]
            economia_news_url.append(economia_articles_url)
                
    except Exception as e:
        print(e)   
            
    return economia_news_url

# %%
def getInfo(HOME_URL, economia_news_url): 
        
    try:
        for list_articles in economia_news_url:
            info = []
            for articles in list_articles:
                article_url = HOME_URL + articles
                
                article_response = requests.get(article_url)
                
                if article_response.status_code == 200:
                    article_soup = BeautifulSoup(article_response.content, 'lxml')
                    
                    # Título de la noticia
                    title = article_soup.find('h1').get_text()
                   
                    # Fecha de publicación
                    date = article_soup.find('li', attrs={'class':'fecha-hora'}).get_text()
                    date = re.findall(r'[0-9]*/[0-9]*/[0-9]{2,4}', date)
                    
                    #Resumen de la noticia
                    summary = article_soup.find('p', attrs={'class':'subheader'}).get_text()
                    
                    # Cuerpo de la noticia
                    body = article_soup.find_all('p')[3:-6]
                    body = [pr.get_text() for pr in body]
                    
                    info.append({'title': title, 
                                 'date': date,
                                 'summary': summary,
                                 'body' : body})
                    
    except Exception as e:
                print(e)
                    
    return info

# %%
def runScraper(HOME_URL):
    home = getHomePage(HOME_URL)
    navs = getNavSections(home_soup)
    urls = getSectionNewsLinks(HOME_URL, navs)
    info = getInfo(HOME_URL, urls)
    
    return info

# %%
HOME_URL = 'https://www.panamaamerica.com.pa'

raspado = runScraper(HOME_URL)
# Out:
# 'NoneType' object has no attribute 'get_text'

# %%
import pandas as pd

raspado_df = pd.DataFrame(raspado)
#raspado_df.to_csv("PA_RASPADO/economia_1.csv")
raspado_df
# Out:
#                                                 title         date  \
# 0   ¡Sin tregua! Nuevo incremento en el costo de l...  [23/3/2022]
# 1   Laurentino Cortizo habló de una economía 'sóli...  [23/3/2022]
# 2   SPIA: una huelga en la construcción afectará a...  [23/3/2022]
# 3   Dueños de restaurantes aseguran que están esfo...  [23/3/2022]
# 4   Medidas a largo plazo para enfrentar aumento d...  [23/3/2022]
# 5   Sabonge contrató empresas señaladas en escándalos  [23/3/2022]
# 6   Otra vez aumentará la gasolina, pero se tratar...  [22/3/2022]
# 7   Aplafa: Pandemia deja una crisis de salud ment...  [22/3/2022]
# 8   Transformando los sistemas agroalimentarios: d...  [22/3/2022]
# 9        Los desafíos para innovar en salud en Panamá  [22/3/2022]
# 10  Trabajadores de tierra de Copa ante una inmine...  [21/3/2022]
#
#                                               summary  \
# 0   Precios de la gasolina aumentará hasta tres ce...
# 1   La celebración de Expocomer 2022 es una señal ...
# 2   La SPIA considera que es necesario que prevale...
# 3   Eduardo Vaccaro, dueño de restaurante indicó: ...
# 4   Ante una economía que todavía está en recupera...
# 5   MECO, cuyo propietario está detenido en Costa ...
# 6   Según el Secretario Nacional de Energía, el au...
# 7   Advierten impacto que el cierre de los centros...
# 8   La región podrá enfrentar sus múltiples desafí...
# 9   El evento proyecta la oportunidad para que el ...
# 10  Los trabajadores no logran ponerse de acuerdo ...
#
#                                                  body
# 0   [Nueva alza en el precio del combustible enfre...
# 1   [Expocomer, la feria multisectorial más import...
# 2   [La construcción es un sector importante para ...
# 3   [Los precios en los restaurantes podrían subir...
# 4   [Para esta quincena se tratará de que el preci...
# 5   [Surgen cuestionamientos sobre la gestión de R...
# 6   [El aumento de hace dos semanas osciló entre 1...
# 7   [Trastornos depresivos, conducta bipolar, inte...
# 8   [América Latina sigue produciendo a pesar de l...
# 9   ["Es una oportunidad histórica de enfocar part...
# 10  [Son más de 800 trabajadores los que se irían ...

# %%
#a=getHomePage(HOME_URL)
#b = getNavSections(a)
#c = getSectionNewsLinks(HOME_URL, b)
#getInfo(HOME_URL, c)

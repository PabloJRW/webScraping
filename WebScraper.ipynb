# %% [markdown]
# # Web Scraper - Página12.com

# %% [markdown]
# Web Scraper de un periódico argentino digital. Del cual extraigo:
# <ul>
#     <li>Título de noticia</li>
#     <li>Fecha de publicación</li>
#     <li>Redactor de noticia</li>
#     <li>Redacción de la noticia</li>
# </ul>

# %% [markdown]
# ## Líbrerias

# %%
import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# ## Desarrollo

# %%
# Enlace del períodico digital
HOME_URL = 'https://pagina12.com.ar'

# %%
# Consulta al enlace
response = requests.get(HOME_URL)
print('Status Code: '+str(response.status_code))
# Out:
# Status Code: 200

# %%
# Página
soup = BeautifulSoup(response.content, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Página12 | La otra mirada
#   </title>
#   <meta content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg" name="google-site-verification"/>
#   <script type="application/ld+json">
#    {"@context": "http://schema.org","@type": "Organization","name": "Página12","url": "https://www.pagina12.com.ar","logo": {"@type": "ImageObject","url": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png","width": "600","height": "60"},"sameAs":["https://twitter.com/pagina12","https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg","https://www.instagram.com/pagina12/","https://www.facebook.com/Pagina12ok/"]}
#   </script>
#   <meta content="Notas focalizadas en el quehacer político de la Argentina." name="description" property="description"/>
#   <meta content="1541638399393436" name="fb:pages" property="fb:pages"/>
#   <meta content="es_AR" name="og:locale" property="og:locale"/>
# ...

# %% [markdown]
# ### Secciones de navegación

# %%
secciones = soup.find('ul', attrs={'class':'horizontal-list main-sections hide-on-dropdown'}).find_all('li')
secciones = [s.a.get('href') for s in secciones]
secciones
# Out:
# ['https://www.pagina12.com.ar/secciones/el-pais',
#  'https://www.pagina12.com.ar/secciones/economia',
#  'https://www.pagina12.com.ar/secciones/sociedad',
#  'https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos',
#  'https://www.pagina12.com.ar/secciones/deportes',
#  'https://www.pagina12.com.ar/secciones/el-mundo',
#  'https://www.pagina12.com.ar/secciones/psicologia']

# %% [markdown]
# ### Click -> Sección Sociedad

# %%
sociedad_response = requests.get(secciones[2])
sociedad_response
# Out:
# <Response [200]>

# %%
soup_sociedad = BeautifulSoup(sociedad_response.content, 'lxml')
print(soup_sociedad.prettify())
# Out:
# <!DOCTYPE html>
# <html amp="" lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Sociedad | Página12
#   </title>
#   <!-- DUST PATH: /usr/src/app/src/widgets/fc_jsonLD.dust/ -->
#   <script type="application/ld+json">
#    {"@context": "http://schema.org","@type": "Organization","name": "Página12","url": "https://www.pagina12.com.ar","logo": {"@type": "ImageObject","url": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png","width": "600","height": "60"},"sameAs":["https://twitter.com/pagina12","https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg","https://www.instagram.com/pagina12/","https://www.facebook.com/Pagina12ok/"]}
#   </script>
#   <script type="application/ld+json">
# ...

# %%
# Página de una sección
sociedad_page = soup_sociedad.find('div', attrs={'id':'main-content'}).find_all('article')
#print(sociedad_page.prettify())
sociedad_page
# Out:
# [<article class="article-item article-item--main"><!-- Image --><div class="article-item__header deco-bar-here"><a href="/410390-temporal-un-muerto-en-cordoba-y-destrozos-en-varias-provinci"><!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_displayImg_amp.dust/ --><amp-img alt="Un árbol caído sobre un auto, en Bahía Blanca. (Fuente: Gentileza La Nueva)" class="" height="313" layout="responsive" src="https://images.pagina12.com.ar/styles/focal_3_2_470x313/public/2022-03/424233-whatsapp-20image-202022-03-24-20at-2011-01-05.jpeg?itok=M3157DBl" srcset="https://images.pagina12.com.ar/styles/focal_3_2_300x200/public/2022-03/424233-whatsapp-20image-202022-03-24-20at-2011-01-05.jpeg?itok=3TAf51Y3 300w, https://images.pagina12.com.ar/styles/focal_3_2_470x313/public/2022-03/424233-whatsapp-20image-202022-03-24-20at-2011-01-05.jpeg?itok=M3157DBl 470w" width="470"><noscript><img alt="Un árbol caído sobre un auto, en Bahía Blanca. (Fuente: Gentileza La Nueva)" height="313" 
# ...

# %% [markdown]
# ### Artículos de sección

# %%
# Artículos de una sección
sociedad_articles = [article.a.get('href') for article in sociedad_page]
sociedad_articles
# Out:
# ['/410390-temporal-un-muerto-en-cordoba-y-destrozos-en-varias-provinci',
#  '/410386-el-smn-emitio-alertas-meteorologicas-para-caba-y-8-provincia',
#  '/410378-por-que-es-feriado-el-24-de-marzo',
#  '/410352-clima-en-buenos-aires-el-pronostico-del-tiempo-para-este-jue',
#  '/410369-del-terror-al-amanecer',
#  '/410035-efemerides-de-hoy-que-paso-un-24-de-marzo',
#  '/410186-coronavirus-se-registraron-3603-nuevos-contagios-y-78-muerto',
#  '/410230-indemnizaran-a-un-trabajador-puntano-aquejado-por-el-sindrom',
#  '/410239-la-ciudad-clausuro-el-mercado-de-economia-solidaria-de-bonpl',
#  '/410071-detuvieron-al-principal-sospechoso-del-crimen-del-ex-puma-fe',
#  '/410260-violacion-grupal-uno-de-los-acusados-pidio-la-nulidad-de-su-']

# %%
# Artículo de noticia
url_news = sociedad_articles[0]
url_news
# Out:
# '/410390-temporal-un-muerto-en-cordoba-y-destrozos-en-varias-provinci'

# %%
nota = HOME_URL + url_news
r_nota = requests.get(nota)
nota = BeautifulSoup(r_nota.content, 'lxml')
print(nota.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Temporal: un muerto en Córdoba y destrozos en varias provincias | La provincia mediterránea, Bahía Blanca y San Juan informaron sobre los efectos del paso del fenómeno meteorológico, y en Mar del Plata hubo cortes de luz y debieron suspender la "carrera de Miguel" | Página12
#   </title>
#   <link href="https://www.pagina12.com.ar/410390-temporal-un-muerto-en-cordoba-y-destrozos-en-varias-provinci" rel="canonical"/>
#   <link href="https://www.pagina12.com.ar/410390-temporal-un-muerto-en-cordoba-y-destrozos-en-varias-provinci?amp=1" rel="amphtml"/>
#   <script async="" src="https://news.google.com/swg/js/v1/swg.js">
#   </script>
#   <script type="application/ld+json">
# ...

# %% [markdown]
# ### Título de la noticia

# %%
# Título de la noticia
title = nota.find('title').get_text() 
title
# Out:
# 'Temporal: un muerto en Córdoba y destrozos en varias provincias | La provincia mediterránea, Bahía Blanca y San Juan informaron sobre los efectos del paso del fenómeno meteorológico, y en Mar del Plata hubo cortes de luz y debieron suspender la "carrera de Miguel" | Página12'

# %% [markdown]
# ### Fecha de publicación

# %%
date = nota.find('span').get_text()
date
# Out:
# '24 de marzo de 2022'

# %% [markdown]
# ### Resumen de la noticia

# %%
summary = nota.find('div',attrs={'class':'col 2-col'}).find('h3').get_text()
summary
# Out:
# ''

# %% [markdown]
# ### Cuerpo de la noticia

# %%
cuerpo = nota.find('div', attrs={'class':'article-main-content article-text'}).find_all('p')
cuerpo = [p.get_text() for p in cuerpo]
cuerpo
# Out:
# ['Un camionero muerto en Córdoba, y voladura de techos, caída de postes y de árboles en el sur de esa provincia, en Bahía Blanca, San Juan y Mar del Plata, fueron los efectos de temporales que se desataron anoche, según se informó oficialmente desde esas localidades.',
#  'De acuerdo a los datos suministrados por la policía cordobesa, un camionero de 39 años que circulaba por la ruta en las cercanías de la localidad de La Cesira, en el departamento Roque Sáenz Peña, murió electrocutado cuando el intenso viento desprendió un poste de electricidad que cayó sobre el vehículo.',
#  'El temporal comenzó alrededor de las 22 y se desplegó por Achiras, Berrotarán, Del Campillo, Huinca Renancó, Río Cuarto, Sampacho y Villa Huidobro, entre otros poblados, y con menor impacto en la zona del Valle de Calamuchita.',
# ...

# %% [markdown]
# ## Scraper

# %%
def getHomePage(HOME_URL):
    """Recibe el enlace de la página y hace la consulta"""
    
    try:
        response = requests.get(HOME_URL) # Consulta a la página a scrapear
        if response.status_code == 200:
            home_soup = BeautifulSoup(response.content, 'lxml')
            return home_soup
        
    except Exception as e:
        print(e)

# %%
def getNavSections(home_soup):
    """Recibe la sopa de la página principal, retorna los enlaces de las secciones"""
    
    try:
        nav_sect_soup = home_soup.find('ul', attrs={'class':'horizontal-list main-sections hide-on-dropdown'}).find_all('li')
        nav_sections = [section.a.get('href') for section in nav_sect_soup]
        
    except Exception as e:
        print(e)
        
    return nav_sections

# %%
def getSectionNewsLinks(sections):
    """Recibe los enlaces de las secciones, retorna los enlaces de las noticias en ellas """
    
    links_to_news = []
    for section in sections:
        section_response = requests.get(section) # Consulta las secciones
        
        try:
            if section_response.status_code == 200:
                section_soup = BeautifulSoup(section_response.content, 'lxml')
                articles = section_soup.find('div', attrs={'id':'main-content'}).find_all('article')
                news_links = [i.a.get('href') for i in articles]
                links_to_news.append(news_links)
                
        except Exception as e:
            print(e)   
            
    return links_to_news

# %%
def getInfo(HOME_URL, sections_news_links):
    
    info = []
    for list_section_links in sections_news_links:
        for article in list_section_links:
        
            news_response = requests.get(HOME_URL + article)
            
            try:
                if news_response.status_code == 200:
                    article_soup = BeautifulSoup(news_response.content, 'lxml')
                    
                    # Título de la noticia
                    title = article_soup.find('title').get_text() 
                    title = re.sub(r'Página12', '', title)
                    
                    # Fecha de publicación
                    date = article_soup.find('span').get_text()
                    
                    #Resumen de la noticia
                    summary = article_soup.find('div',attrs={'class':'col 2-col'}).find('h3').get_text()
                    
                    # Cuerpo de la noticia
                    body = article_soup.find('div', attrs={'class':'article-main-content article-text'}).find_all('p')
                    body = [p.get_text() for p in body]
                    
                    info.append({'title': title, 
                                 'date': date,
                                 'summary': summary,
                                 'body' : body})
                    
            except Exception as e:
                print(e)
                    
    return info

# %%
def runScraper(HOME_URL):
    home = getHomePage(HOME_URL)
    navs = getNavSections(home)
    sects = getSectionNewsLinks(navs)
    info = getInfo(HOME_URL, sects)
    
    return info

# %%
HOME_URL = 'https://www.pagina12.com.ar'

# %%
raspado = runScraper(HOME_URL)
# Out:
# 'NoneType' object has no attribute 'find_all'

# %%
import pandas as pd

raspado = pd.DataFrame(raspado)
raspado.to_csv("Raspado_Pagina12/'24 de marzo 2022.csv'")
